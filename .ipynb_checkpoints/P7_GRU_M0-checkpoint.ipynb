# %% [raw]
# GRU M0 baseline Final

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
from datetime import date
import math
import pandas_datareader as web
import yfinance as yf
import time  # Import the time module
import os  # Import the os module
from sklearn.model_selection import TimeSeriesSplit

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from pathlib import Path

# %%
# reshape 2D dataset (samples + features) en 3D (samples/time step + features + séquence) 
# en ajoutant la dimension fenêtre/séquence (longueur est window_size) N, pour prédire N+1. 
# y_pos est la position de colonnes du target. Normalament la prémière colonne
# dataset.shape[0] est le nombre des échantillons
def rnn_3D_data(dataset, window_size, y_pos=0): 
    X = []
    y = []
    for i in range(window_size, dataset.shape[0]):
        X.append(dataset[i-window_size: i])
        y.append(dataset[i, y_pos])
    X, y = np.array(X), np.array(y)
    return X, y

# %%
def data_retrieve(stock, start_date, end_date): 

# Define the list of tickers for the stocks you want to fetch data for
    tickers = [stock]

    # Define the list of stock indices and other features
    indices = ['^GSPC', '^DJI', '^IXIC', 'DX-Y.NYB', '^GDAXI', '^FTSE', '^N225', '^VIX']
    commodities = ['GC=F', 'BZ=F']
    forex = ['EURUSD=X', 'JPY=X']

    symbols = indices + commodities + forex
    # Fetch the historical data using yfinance for tickers (OHLC and Volume)
    ticker_data = yf.download(tickers, start=start_date, end=end_date)

    # Fetch the historical data using yfinance for indices and commodities (Close Price)
    close_data = yf.download(symbols, start=start_date, end=end_date)['Adj Close']

# Concatenate the close_data with the ticker_data to include Close Price for all symbols
    all_data = pd.concat([ticker_data, close_data], axis=1)

# Print the data
    return all_data

# %%
# Définir le modèle avec cycle scaling, reshing, compile, entrainement
def GRU_M0(df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout):

    scalar = MinMaxScaler()

    data_training_scaled = scalar.fit_transform(data_training)
    X_train, y_train = rnn_3D_data(data_training_scaled, window_size=win_size, y_pos=3)
    
    # add the winodw before test data
    data_test = pd.concat([data_training.tail(win_size), data_testing], ignore_index=True)
    data_test_scaled = scalar.fit_transform(data_test)
    X_test, y_test = rnn_3D_data(data_test_scaled, window_size=win_size, y_pos=3)
    
    y_scaler_train = MinMaxScaler()
    y_scaler_train.fit(data_training["Close"].values.reshape(-1, 1))
    y_scaler_test = MinMaxScaler()
    y_scaler_test.fit(data_test["Close"].values.reshape(-1, 1))
    
    model = Sequential()
    
    model.add(GRU(units = num_cell, activation = 'relu', input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units = 1))

    start_time = time.time()
    # Compiling the RNN
    model.compile(optimizer = 'adam', loss = 'mean_squared_error')
    
    rnn_path = (results_path / 'gru_M0.h5').as_posix()
    checkpointer = ModelCheckpoint(filepath=rnn_path,
                               verbose=1,
                               monitor='val_loss',
                               save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=20,
                              restore_best_weights=True)
    
    lstm_training = model.fit(X_train, y_train, epochs=num_epoch, batch_size = batch_size,\
                        shuffle=True, validation_data=(X_test, y_test),\
                        callbacks=[early_stopping, checkpointer],
                        verbose=1)     
    
    end_time = time.time()
    execution_time = end_time - start_time   
    
    # evaluer le modèle
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(lstm_training.history).pow(.5)
    loss_history.index += 1
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    
    resultat = ['GRU_M0',win_size,num_cell, num_epoch, batch_size, dropout, round(best_rmse, 4), round(execution_time, 0)]
    return model, resultat, lstm_training, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test

# %% [markdown]
# # Parameters

# %%
win_size = 60
num_epoch = 100
num_cell = 50
batch_size = 64
dropout = 0.5
split_date = '2020-12-31'
# pour stocker les modèles 
results_path = Path('models', 'GRU_M0')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# # 1. Raw data collection

# %%
start_date = datetime.datetime(2010, 1, 2)
end_date = datetime.datetime.today()

# %%
raw_data = yf.download('^GSPC', start=start_date, end=end_date)
raw_data.to_parquet('sp500_data.parquet')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
raw_data.to_parquet('sp500_data.parquet')

# %%
data = pd.read_parquet('sp500_data.parquet')

# %%
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('There are {} number of days in the dataset.'.format(data.shape[0]))
# Out:
# There are 3429 number of days in the dataset.

# %%
plt.figure(figsize=(28, 12))#, dpi=100)
plt.plot(data.index, data['Adj Close'], label='SP500')
plt.xlabel('Date')
plt.ylabel('Rs')
plt.title('sp500')
plt.legend()
plt.show()

# %%
df = data.copy()
df = df.dropna()
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('Total dataset has {} samples, and {} features.'.format(df.shape[0], \
                                                              df.shape[1]))
# Out:
# Total dataset has 3429 samples, and 6 features.

# %% [markdown]
# # 2. Feature engineering

# %%
FE_df = df

# %%
len(FE_df)
# Out:
# 3429

# %% [markdown]
# # 3. Modèle processing

# %% [markdown]
# ## 3.1. Data split

# %%
data_training = FE_df[FE_df.index < split_date].copy()
data_training.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
y_train_real_all = data_training["Close"].values.reshape(-1, 1)

# %%
#remove the first win_size row which are without prediction
y_train_real = y_train_real_all[win_size:]

# %%
data_testing = FE_df[FE_df.index >= split_date].copy()
data_testing.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
# 2021-01-04  3764.610107  3769.989990  3662.709961  3700.649902  3700.649902
# 2021-01-05  3698.020020  3737.830078  3695.070068  3726.860107  3726.860107
# 2021-01-06  3712.199951  3783.040039  3705.340088  3748.139893  3748.139893
# 2021-01-07  3764.709961  3811.550049  3764.709961  3803.790039  3803.790039
#
#                 Volume
# Date
# 2020-12-31  3179040000
# 2021-01-04  5015000000
# 2021-01-05  4591020000
# 2021-01-06  6064110000
# 2021-01-07  5099160000

# %%
y_test_real = data_testing["Close"].values.reshape(-1, 1)

# %% [raw]
# Normalization: MinMaxScaler transforms your data to a specific range, typically between 0 and 1. This is especially useful when you have features with different scales, as it ensures that all features are on a similar scale. This can be important for algorithms that are sensitive to the scale of features, like gradient-based optimization algorithms.
# Applied to all features.

# %%
#scalar = MinMaxScaler()

#data_training_scaled = scalar.fit_transform(data_training)

# %% [markdown]
# ## 3.2 Data scaling, reshaping, Model

# %%
lstm_model, resultat, model_history, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test = \
GRU_M0(FE_df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout)
# Out:
# Epoch 1/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0262
# Epoch 1: val_loss improved from inf to 0.00522, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 8s 77ms/step - loss: 0.0261 - val_loss: 0.0052
# Epoch 2/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.0003e-04
# Epoch 2: val_loss improved from 0.00522 to 0.00227, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 43ms/step - loss: 4.9699e-04 - val_loss: 0.0023
# Epoch 3/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3192e-04
# Epoch 3: val_loss improved from 0.00227 to 0.00206, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 3s 59ms/step - loss: 2.3134e-04 - val_loss: 0.0021
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 1.9726e-04
# Epoch 4: val_loss improved from 0.00206 to 0.00195, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 58ms/step - loss: 1.9726e-04 - val_loss: 0.0019
# Epoch 5/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.7721e-04
# Epoch 5: val_loss improved from 0.00195 to 0.00185, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 41ms/step - loss: 1.7634e-04 - val_loss: 0.0018
# Epoch 6/100
# 43/43 [==============================] - ETA: 0s - loss: 1.6466e-04
# Epoch 6: val_loss improved from 0.00185 to 0.00177, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 44ms/step - loss: 1.6466e-04 - val_loss: 0.0018
# Epoch 7/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.5690e-04
# Epoch 7: val_loss improved from 0.00177 to 0.00173, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 50ms/step - loss: 1.5743e-04 - val_loss: 0.0017
# Epoch 8/100
# 43/43 [==============================] - ETA: 0s - loss: 1.4819e-04
# Epoch 8: val_loss improved from 0.00173 to 0.00166, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 41ms/step - loss: 1.4819e-04 - val_loss: 0.0017
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 1.4054e-04
# Epoch 9: val_loss improved from 0.00166 to 0.00161, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 54ms/step - loss: 1.4054e-04 - val_loss: 0.0016
# Epoch 10/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.3909e-04
# Epoch 10: val_loss improved from 0.00161 to 0.00157, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 54ms/step - loss: 1.3860e-04 - val_loss: 0.0016
# Epoch 11/100
# 43/43 [==============================] - ETA: 0s - loss: 1.3258e-04
# Epoch 11: val_loss improved from 0.00157 to 0.00153, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 42ms/step - loss: 1.3258e-04 - val_loss: 0.0015
# Epoch 12/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.2619e-04
# Epoch 12: val_loss improved from 0.00153 to 0.00150, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 46ms/step - loss: 1.2717e-04 - val_loss: 0.0015
# Epoch 13/100
# 43/43 [==============================] - ETA: 0s - loss: 1.2311e-04
# Epoch 13: val_loss improved from 0.00150 to 0.00147, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 53ms/step - loss: 1.2311e-04 - val_loss: 0.0015
# Epoch 14/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1942e-04
# Epoch 14: val_loss improved from 0.00147 to 0.00144, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 58ms/step - loss: 1.1899e-04 - val_loss: 0.0014
# Epoch 15/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.2184e-04
# Epoch 15: val_loss improved from 0.00144 to 0.00143, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 3s 65ms/step - loss: 1.2269e-04 - val_loss: 0.0014
# Epoch 16/100
# 43/43 [==============================] - ETA: 0s - loss: 1.2389e-04
# Epoch 16: val_loss improved from 0.00143 to 0.00140, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 57ms/step - loss: 1.2389e-04 - val_loss: 0.0014
# Epoch 17/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1822e-04
# Epoch 17: val_loss improved from 0.00140 to 0.00139, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 42ms/step - loss: 1.1859e-04 - val_loss: 0.0014
# Epoch 18/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1793e-04
# Epoch 18: val_loss improved from 0.00139 to 0.00136, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 3s 71ms/step - loss: 1.1751e-04 - val_loss: 0.0014
# Epoch 19/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1121e-04
# Epoch 19: val_loss did not improve from 0.00136
# 43/43 [==============================] - 2s 49ms/step - loss: 1.1120e-04 - val_loss: 0.0014
# Epoch 20/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1324e-04
# Epoch 20: val_loss improved from 0.00136 to 0.00133, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 47ms/step - loss: 1.1286e-04 - val_loss: 0.0013
# Epoch 21/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1908e-04
# Epoch 21: val_loss improved from 0.00133 to 0.00133, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 49ms/step - loss: 1.1869e-04 - val_loss: 0.0013
# Epoch 22/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0890e-04
# Epoch 22: val_loss improved from 0.00133 to 0.00131, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 47ms/step - loss: 1.0851e-04 - val_loss: 0.0013
# Epoch 23/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0543e-04
# Epoch 23: val_loss improved from 0.00131 to 0.00129, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 39ms/step - loss: 1.0543e-04 - val_loss: 0.0013
# Epoch 24/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0434e-04
# Epoch 24: val_loss improved from 0.00129 to 0.00128, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 50ms/step - loss: 1.0434e-04 - val_loss: 0.0013
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0394e-04
# Epoch 25: val_loss improved from 0.00128 to 0.00127, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 1.0376e-04 - val_loss: 0.0013
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0233e-04
# Epoch 26: val_loss did not improve from 0.00127
# 43/43 [==============================] - 2s 43ms/step - loss: 1.0233e-04 - val_loss: 0.0013
# Epoch 27/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.6745e-05
# Epoch 27: val_loss improved from 0.00127 to 0.00126, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 51ms/step - loss: 1.0135e-04 - val_loss: 0.0013
# Epoch 28/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0201e-04
# Epoch 28: val_loss improved from 0.00126 to 0.00126, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 46ms/step - loss: 1.0218e-04 - val_loss: 0.0013
# Epoch 29/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0498e-04
# Epoch 29: val_loss did not improve from 0.00126
# 43/43 [==============================] - 2s 40ms/step - loss: 1.0498e-04 - val_loss: 0.0013
# Epoch 30/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1230e-04
# Epoch 30: val_loss improved from 0.00126 to 0.00123, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 48ms/step - loss: 1.1200e-04 - val_loss: 0.0012
# Epoch 31/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.8719e-05
# Epoch 31: val_loss improved from 0.00123 to 0.00122, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 46ms/step - loss: 9.9268e-05 - val_loss: 0.0012
# Epoch 32/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0333e-04
# Epoch 32: val_loss improved from 0.00122 to 0.00121, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 43ms/step - loss: 1.0290e-04 - val_loss: 0.0012
# Epoch 33/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.8644e-05
# Epoch 33: val_loss did not improve from 0.00121
# 43/43 [==============================] - 2s 52ms/step - loss: 9.9681e-05 - val_loss: 0.0012
# Epoch 34/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0181e-04
# Epoch 34: val_loss improved from 0.00121 to 0.00119, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 51ms/step - loss: 1.0181e-04 - val_loss: 0.0012
# Epoch 35/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0047e-04
# Epoch 35: val_loss improved from 0.00119 to 0.00118, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 42ms/step - loss: 1.0047e-04 - val_loss: 0.0012
# Epoch 36/100
# 43/43 [==============================] - ETA: 0s - loss: 9.6564e-05
# Epoch 36: val_loss improved from 0.00118 to 0.00117, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 53ms/step - loss: 9.6564e-05 - val_loss: 0.0012
# Epoch 37/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0432e-04
# Epoch 37: val_loss improved from 0.00117 to 0.00117, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 3s 66ms/step - loss: 1.0432e-04 - val_loss: 0.0012
# Epoch 38/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0188e-04
# Epoch 38: val_loss improved from 0.00117 to 0.00116, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 41ms/step - loss: 1.0188e-04 - val_loss: 0.0012
# Epoch 39/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.7026e-05
# Epoch 39: val_loss did not improve from 0.00116
# 43/43 [==============================] - 2s 45ms/step - loss: 9.7796e-05 - val_loss: 0.0012
# Epoch 40/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1092e-04
# Epoch 40: val_loss did not improve from 0.00116
# 43/43 [==============================] - 2s 50ms/step - loss: 1.1054e-04 - val_loss: 0.0012
# Epoch 41/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0508e-04
# Epoch 41: val_loss did not improve from 0.00116
# 43/43 [==============================] - 2s 46ms/step - loss: 1.0659e-04 - val_loss: 0.0013
# Epoch 42/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.
100
# 42/43 [============================>.] - ETA: 0s - loss: 9.7279e-05
# Epoch 58: val_loss did not improve from 0.00107
# 43/43 [==============================] - 2s 45ms/step - loss: 9.6921e-05 - val_loss: 0.0012
# Epoch 59/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0842e-04
# Epoch 59: val_loss improved from 0.00107 to 0.00106, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 41ms/step - loss: 1.0842e-04 - val_loss: 0.0011
# Epoch 60/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0492e-04
# Epoch 60: val_loss did not improve from 0.00106
# 43/43 [==============================] - 2s 46ms/step - loss: 1.0506e-04 - val_loss: 0.0011
# Epoch 61/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0285e-04
# Epoch 61: val_loss did not improve from 0.00106
# 43/43 [==============================] - 2s 47ms/step - loss: 1.0327e-04 - val_loss: 0.0011
# Epoch 62/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.8710e-05
# Epoch 62: val_loss did not improve from 0.00106
# 43/43 [==============================] - 2s 47ms/step - loss: 9.8411e-05 - val_loss: 0.0011
# Epoch 63/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.4576e-05
# Epoch 63: val_loss did not improve from 0.00106
# 43/43 [==============================] - 2s 47ms/step - loss: 9.4072e-05 - val_loss: 0.0011
# Epoch 64/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0821e-04
# Epoch 64: val_loss did not improve from 0.00106
# 43/43 [==============================] - 2s 49ms/step - loss: 1.0821e-04 - val_loss: 0.0011
# Epoch 65/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0628e-04
# Epoch 65: val_loss did not improve from 0.00106
# 43/43 [==============================] - 2s 43ms/step - loss: 1.0603e-04 - val_loss: 0.0011
# Epoch 66/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0740e-04
# Epoch 66: val_loss did not improve from 0.00106
# 43/43 [==============================] - 2s 45ms/step - loss: 1.0740e-04 - val_loss: 0.0011
# Epoch 67/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0360e-04
# Epoch 67: val_loss improved from 0.00106 to 0.00105, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 56ms/step - loss: 1.0338e-04 - val_loss: 0.0010
# Epoch 68/100
# 43/43 [==============================] - ETA: 0s - loss: 9.1731e-05
# Epoch 68: val_loss did not improve from 0.00105
# 43/43 [==============================] - 2s 40ms/step - loss: 9.1731e-05 - val_loss: 0.0013
# Epoch 69/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.0576e-04
# Epoch 69: val_loss did not improve from 0.00105
# 43/43 [==============================] - 2s 46ms/step - loss: 1.0558e-04 - val_loss: 0.0011
# Epoch 70/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1863e-04
# Epoch 70: val_loss did not improve from 0.00105
# 43/43 [==============================] - 2s 47ms/step - loss: 1.1816e-04 - val_loss: 0.0011
# Epoch 71/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.8754e-05
# Epoch 71: val_loss did not improve from 0.00105
# 43/43 [==============================] - 2s 48ms/step - loss: 9.8554e-05 - val_loss: 0.0011
# Epoch 72/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0342e-04
# Epoch 72: val_loss did not improve from 0.00105
# 43/43 [==============================] - 2s 58ms/step - loss: 1.0342e-04 - val_loss: 0.0011
# Epoch 73/100
# 43/43 [==============================] - ETA: 0s - loss: 9.3430e-05
# Epoch 73: val_loss improved from 0.00105 to 0.00105, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 58ms/step - loss: 9.3430e-05 - val_loss: 0.0010
# Epoch 74/100
# 43/43 [==============================] - ETA: 0s - loss: 9.8081e-05
# Epoch 74: val_loss improved from 0.00105 to 0.00104, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 41ms/step - loss: 9.8081e-05 - val_loss: 0.0010
# Epoch 75/100
# 42/43 [============================>.] - ETA: 0s - loss: 9
val_loss did not improve from 0.00101
# 43/43 [==============================] - 2s 40ms/step - loss: 9.3405e-05 - val_loss: 0.0010
# Epoch 97/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.3610e-05
# Epoch 97: val_loss did not improve from 0.00101
# 43/43 [==============================] - 2s 41ms/step - loss: 9.3362e-05 - val_loss: 0.0011
# Epoch 98/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.1591e-04
# Epoch 98: val_loss did not improve from 0.00101
# 43/43 [==============================] - 2s 39ms/step - loss: 1.1569e-04 - val_loss: 0.0011
# Epoch 99/100
# 43/43 [==============================] - ETA: 0s - loss: 1.0525e-04
# Epoch 99: val_loss improved from 0.00101 to 0.00101, saving model to models/GRU_M0\gru_M0.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 1.0525e-04 - val_loss: 0.0010
# Epoch 100/100
# 43/43 [==============================] - ETA: 0s - loss: 1.2185e-04
# Epoch 100: val_loss did not improve from 0.00101
# 43/43 [==============================] - 2s 43ms/step - loss: 1.2185e-04 - val_loss: 0.0010

# %% [markdown]
# # 4. Evaluation performance

# %% [markdown]
# ## 4.1. Scaled performance

# %%
def lstm_scaled_perfomance(model_history, start_epoch=1):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(start_epoch, start_epoch + len(model_history.history['loss']))
    
    # loss, val_loss 
    axs[0].plot(epochs, model_history.history['loss'], label='Training Loss')
    axs[0].plot(epochs, model_history.history['val_loss'],  label='Validation Loss')
    axs[0].set_title('Model Loss')
    axs[0].set_ylabel('Loss')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validation'], loc='best')
    
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(model_history.history).pow(.5)
    loss_history.index += 1    
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    best_epoch = loss_history.val_loss.idxmin()    
    title = f'Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
    loss_history.columns=['Training RMSE', 'Validation RMSE']
    
    loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=axs[1])    
    axs[1].axvline(best_epoch, ls='--', lw=1, c='k')
    
    sns.despine()
    fig.tight_layout()    
    plt.show()
    return best_rmse, best_epoch

# %%
best_rmse, best_epoch = lstm_scaled_perfomance(model_history)

# %%
y_train_predict_scaled = lstm_model.predict(X_train)
y_test_predict_scaled = lstm_model.predict(X_test)
# Out:
# 85/85 [==============================] - 2s 9ms/step
# 21/21 [==============================] - 0s 8ms/step

# %% [raw]
# Spearman's rank correlation coefficient, often denoted as ρ (rho), is a statistical measure that quantifies the strength and direction of a monotonic relationship between two variables. Instead of considering the actual values of the variables, it considers their ranks.
#
# The Spearman's rank correlation coefficient can take values between -1 and 1:
#
# ρ = 1: Perfect monotonic increasing relationship.
# ρ = -1: Perfect monotonic decreasing relationship.
# ρ = 0: No monotonic relationship.

# %%
from scipy.stats import spearmanr
train_ic = spearmanr(y_train, y_train_predict_scaled)[0]
test_ic = spearmanr(y_test, y_test_predict_scaled)[0]
print(f'Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}')
# Out:
# Train IC: 0.9991 | Test IC: 0.9843

# %%
import matplotlib.pyplot as plt

# Plotting the train and test predictions against actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_predict_scaled, label='Train Predictions')
plt.scatter(y_test, y_test_predict_scaled, label='Test Predictions')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Spearman rank correlation (IC)')
plt.legend()
plt.show()

# %% [markdown]
# ## 4.2. Rescaled performance

# %%
def lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    axs[0].plot(y_train_real, color = 'red', label = 'Real SP500 Price')
    axs[0].plot(y_train_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[0].set_title('SP500 Train Price Prediction')
    axs[0].set_ylabel('Price')
    axs[0].set_xlabel('Time')
    axs[0].legend(['Real', 'Predict'], loc='best')

    axs[1].plot(y_test_real, color = 'red', label = 'Real SP500 Price')
    axs[1].plot(y_test_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[1].set_title('SP500 Test Price Prediction')
    axs[1].set_ylabel('Price')
    axs[1].set_xlabel('Time')
    axs[1].legend(['Real', 'Predict'], loc='best')

    plt.legend()  
    plt.show()
    return

# %%
y_test_predict = y_scaler_test.inverse_transform(y_test_predict_scaled)
y_train_predict = y_scaler_train.inverse_transform(y_train_predict_scaled)

# %%
lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict)

# %%
train_rmse_scaled = np.sqrt(lstm_model.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm_model.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE: {train_rmse_scaled:.4f} | Test RMSE: {test_rmse_scaled:.4f}')
# Out:
# Train RMSE: 0.0096 | Test RMSE: 0.0320

# %%
train_rmse = np.sqrt(mean_squared_error(y_train_predict, y_train_real))
test_rmse = np.sqrt(mean_squared_error(y_test_predict, y_test_real))
f'Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}'
# Out:
# 'Train RMSE: 26.05 | Test RMSE: 48.84'

# %%
def RMSE_plot(y_train_real, y_train_predict, y_test_real, y_test_predict, train_rmse, test_rmse):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))

    sns.distplot(y_train_predict.squeeze() - y_train_real, ax=axs[0])
    axs[0].set_title('Train Error')  
    axs[0].text(x=.03, y=.92, s=f'Train RMSE ={train_rmse:.4f}', transform=axs[0].transAxes)

    sns.distplot(y_test_predict.squeeze()- y_test_real, ax=axs[1])
    axs[1].set_title('Test Error')  
    axs[1].text(x=.03, y=.92, s=f'Test RMSE ={test_rmse:.4f}', transform=axs[1].transAxes)
    
    sns.despine()
    plt.show()
    return

# %%
RMSE_plot(y_train_real, y_train_predict, y_test_real, y_test_predict, train_rmse, test_rmse)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7836\635383245.py in <module>
# ----> 1 RMSE_plot(y_train_real, y_train_predict, y_test_real, y_test_predict, train_rmse, test_rmse)
#
# ~\AppData\Local\Temp\ipykernel_7836\4237170145.py in RMSE_plot(y_train_real, y_train_predict, y_test_real, y_test_predict, train_rmse, test_rmse)
#       4     train_error = y_train_predict.squeeze() - y_train_real
#       5     train_error = train_error[~np.isinf(train_error) & ~np.isnan(train_error)]
# ----> 6     sns.distplot(train_error, ax=axs[0], kde=True)
#       7     axs[0].set_title('Train Error')
#       8     axs[0].text(x=.03, y=.92, s=f'Train RMSE = {train_rmse:.4f}', transform=axs[0].transAxes)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2685     if kde:
#    2686         kde_color = kde_kws.pop("color", color)
# -> 2687         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#    2688         if kde_color != color:
#    2689             kde_kws["color"] = kde_color
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1768             plot_kws["color"] = color
#    1769
# -> 1770         p.plot_univariate_density(
#    1771             multiple=multiple,
#    1772             common_norm=common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, legend, estimate_kws, **plot_kws)
#     926
#     927         # Do the computation
# --> 928         densities = self._compute_univariate_density(
#     929             self.data_variable,
#     930             common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     301         densities = {}
#     302
# --> 303         for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#     304
#     305             # Extract the data points from this sub set and remove nulls
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in comp_data(self)
#    1052                 # Use the converter assigned to the axis to get a float representation
#    1053                 # of the data, passing np.nan or pd.NA through (pd.NA becomes np.nan)
# -> 1054                 with pd.option_context('mode.use_inf_as_null', True):
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in __enter__(self)
#     439
#     440     def __enter__(self) -> None:
# --> 441         self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     442
#     443         for pat, val in self.ops:
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in <listcomp>(.0)
#     439
#     440     def __enter__(self) -> None:
# --> 441         self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     442
#     443         for pat, val in self.ops:
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in _get_option(pat, silent)
#     133
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     136
#     137     # walk the nested dict
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in _get_single_key(pat, silent)
#     119         if not silent:
#     120             _warn_if_deprecated(pat)
# --> 121         raise OptionError(f"No such keys(s): {repr(pat)}")
#     122     if len(keys) > 1:
#     123         raise OptionError("Pattern matched multiple keys")
#
# OptionError: "No such keys(s): 'mode.use_inf_as_null'"

# %%
# rescale predicted value to real value
# Another approximatif way to rescale 
scale = 1/scalar.scale_[4]   # 4th Colonne  is Close
y_train_predict = y_train_predict_scaled*scale
y_train_rescaled = y_train*scale
y_test_rescaled = y_test*scale
