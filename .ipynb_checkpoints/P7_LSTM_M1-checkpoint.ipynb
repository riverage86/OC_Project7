# %% [raw]
# Template Model for LSTM :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
from datetime import date
import math
import pandas_datareader as web
import yfinance as yf

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
def lstm_mse_rsme(lstm_training): 
    fig, ax = plt.subplots(figsize=(12, 4))

    # transforme MSE en RMSE
    loss_history = pd.DataFrame(lstm_training.history).pow(.5)
    loss_history.index += 1

#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    best_epoch = loss_history.val_loss.idxmin()

    title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
    loss_history.columns=['Training RMSE', 'Validation RMSE']
    loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)

#une ligne verticale pointillée (ls='--') sur le graphique pour marquer
#l'époque avec le meilleur RMSE de validation (best_epoch).
    ax.axvline(best_epoch, ls='--', lw=1, c='k')

    sns.despine()
    fig.tight_layout()
    return best_rmse

# %%
# reshape 2D dataset (samples + features) en 3D (samples/time step + features + séquence) 
# en ajoutant la dimension fenêtre/séquence (longueur est window_size) N, pour prédire N+1. 
# y_pos est la position de colonnes du target. Normalament la prémière colonne

def rnn_3D_data(dataset, window_size, y_pos=0): 
    X = []
    y = []
    for i in range(window_size, dataset.shape[0]):
        X.append(dataset[i-window_size: i])
        y.append(dataset[i, y_pos])
    X, y = np.array(X), np.array(y)
    return X, y

# %%
def data_retrieve(stock, start_date, end_date): 

# Define the list of tickers for the stocks you want to fetch data for
    tickers = [stock]

    # Define the list of stock indices and other features
    indices = ['^GSPC', '^DJI', '^IXIC', 'DX-Y.NYB', '^GDAXI', '^FTSE', '^N225', '^VIX']
    commodities = ['GC=F', 'BZ=F']
    forex = ['EURUSD=X', 'JPY=X']

    symbols = indices + commodities + forex
    # Fetch the historical data using yfinance for tickers (OHLC and Volume)
    ticker_data = yf.download(tickers, start=start_date, end=end_date)

    # Fetch the historical data using yfinance for indices and commodities (Close Price)
    close_data = yf.download(symbols, start=start_date, end=end_date)['Adj Close']

# Concatenate the close_data with the ticker_data to include Close Price for all symbols
    all_data = pd.concat([ticker_data, close_data], axis=1)

# Print the data
    return all_data

# %% [markdown]
# # 1. Raw data collection

# %%
start_date = datetime.datetime(2010, 1, 2)
end_date = datetime.datetime.today()

# %%
raw_data = data_retrieve('^GSPC', start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  12 of 12 completed

# %%
raw_data.to_parquet('sp500_data_raw.parquet')

# %%
raw_data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                   Volume       BZ=F   DX-Y.NYB  EURUSD=X         GC=F  \
# Date
# 2010-01-04  3.991400e+09  80.120003  77.529999  1.442398  1117.699951
# 2010-01-05  2.491020e+09  80.589996  77.620003  1.436596  1118.099976
# 2010-01-06  4.972660e+09  81.889999  77.489998  1.440403  1135.900024
# 2010-01-07  5.270680e+09  81.510002  77.910004  1.431803  1133.099976
# 2010-01-08  4.389590e+09  81.370003  77.470001  1.441109  1138.199951
#
#                 JPY=X          ^DJI        ^FTSE       ^GDAXI        ^GSPC  \
# Date
# 2010-01-04  92.495003  10583.959961  5500.299805  6048.299805  1132.989990
# 2010-01-05  91.584999  10572.019531  5522.500000  6031.859863  1136.520020
# 2010-01-06  92.356003  10573.679688  5530.000000  6034.330078  1137.140015
# 2010-01-07  93.389999  10606.860352  5526.700195  6019.359863  1141.689941
# 2010-01-08  92.660004  10618.190430  5534.200195  6037.609863  1144.979980
#
#                   ^IXIC         ^N225       ^VIX
# Date
# 2010-01-04  2308.419922  10654.790039  20.040001
# 2010-01-05  2308.709961  10681.830078  19.350000
# 2010-01-06  2301.090088  10731.450195  19.160000
# 2010-01-07  2300.050049  10681.660156  19.059999
# 2010-01-08  2317.169922  10798.320312  18.129999

# %%
data = pd.read_parquet('sp500_data_raw.parquet')

# %%
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                   Volume       BZ=F   DX-Y.NYB  EURUSD=X         GC=F  \
# Date
# 2010-01-04  3.991400e+09  80.120003  77.529999  1.442398  1117.699951
# 2010-01-05  2.491020e+09  80.589996  77.620003  1.436596  1118.099976
# 2010-01-06  4.972660e+09  81.889999  77.489998  1.440403  1135.900024
# 2010-01-07  5.270680e+09  81.510002  77.910004  1.431803  1133.099976
# 2010-01-08  4.389590e+09  81.370003  77.470001  1.441109  1138.199951
#
#                 JPY=X          ^DJI        ^FTSE       ^GDAXI        ^GSPC  \
# Date
# 2010-01-04  92.495003  10583.959961  5500.299805  6048.299805  1132.989990
# 2010-01-05  91.584999  10572.019531  5522.500000  6031.859863  1136.520020
# 2010-01-06  92.356003  10573.679688  5530.000000  6034.330078  1137.140015
# 2010-01-07  93.389999  10606.860352  5526.700195  6019.359863  1141.689941
# 2010-01-08  92.660004  10618.190430  5534.200195  6037.609863  1144.979980
#
#                   ^IXIC         ^N225       ^VIX
# Date
# 2010-01-04  2308.419922  10654.790039  20.040001
# 2010-01-05  2308.709961  10681.830078  19.350000
# 2010-01-06  2301.090088  10731.450195  19.160000
# 2010-01-07  2300.050049  10681.660156  19.059999
# 2010-01-08  2317.169922  10798.320312  18.129999

# %%
print('There are {} number of days in the dataset.'.format(data.shape[0]))
# Out:
# There are 3551 number of days in the dataset.

# %%
plt.figure(figsize=(28, 12))#, dpi=100)
plt.plot(data.index, data['Adj Close'], label='SP500')
plt.xlabel('Date')
plt.ylabel('Rs')
plt.title('sp500')
plt.legend()
plt.show()

# %%
df = data.copy()

# %%
df = df.dropna()
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                   Volume       BZ=F   DX-Y.NYB  EURUSD=X         GC=F  \
# Date
# 2010-01-04  3.991400e+09  80.120003  77.529999  1.442398  1117.699951
# 2010-01-05  2.491020e+09  80.589996  77.620003  1.436596  1118.099976
# 2010-01-06  4.972660e+09  81.889999  77.489998  1.440403  1135.900024
# 2010-01-07  5.270680e+09  81.510002  77.910004  1.431803  1133.099976
# 2010-01-08  4.389590e+09  81.370003  77.470001  1.441109  1138.199951
#
#                 JPY=X          ^DJI        ^FTSE       ^GDAXI        ^GSPC  \
# Date
# 2010-01-04  92.495003  10583.959961  5500.299805  6048.299805  1132.989990
# 2010-01-05  91.584999  10572.019531  5522.500000  6031.859863  1136.520020
# 2010-01-06  92.356003  10573.679688  5530.000000  6034.330078  1137.140015
# 2010-01-07  93.389999  10606.860352  5526.700195  6019.359863  1141.689941
# 2010-01-08  92.660004  10618.190430  5534.200195  6037.609863  1144.979980
#
#                   ^IXIC         ^N225       ^VIX
# Date
# 2010-01-04  2308.419922  10654.790039  20.040001
# 2010-01-05  2308.709961  10681.830078  19.350000
# 2010-01-06  2301.090088  10731.450195  19.160000
# 2010-01-07  2300.050049  10681.660156  19.059999
# 2010-01-08  2317.169922  10798.320312  18.129999

# %%
print('Total dataset has {} samples, and {} features.'.format(df.shape[0], \
                                                              df.shape[1]))
# Out:
# Total dataset has 3095 samples, and 18 features.

# %% [markdown]
# # 2. Feature engineering

# %% [markdown]
# ## 2.1  Features expansion

# %%
# Calculate technical indicators
def get_technical_indicators(data):
    # Create 7 and 21 days Moving Average
    data['MA7'] = data.iloc[:,4].rolling(window=7).mean()
    data['MA21'] = data.iloc[:,4].rolling(window=21).mean()

    # Create MACD
    data['MACD'] = data.iloc[:,4].ewm(span=26).mean() - data.iloc[:,1].ewm(span=12,adjust=False).mean()

    # Create Bollinger Bands
    data['20SD'] = data.iloc[:, 4].rolling(20).std()
    data['upper_band'] = data['MA21'] + (data['20SD'] * 2)
    data['lower_band'] = data['MA21'] - (data['20SD'] * 2)

    # Create Exponential moving average
    data['EMA'] = data.iloc[:,4].ewm(com=0.5).mean()

    # Create LogMomentum
    data['logmomentum'] = np.log(data.iloc[:,4] - 1)

    return data

# %%
# Getting the Fourier transform features,  applies the Fast Fourier Transform (FFT) on the 'Close' column of
# the input dataset and extracts various Fourier coefficients and their corresponding absolute values and angles,  
# these features can help identify recurring patterns or cyclic behavior in stock prices,
def get_fourier_transfer(dataset):
    # Get the columns for doing fourier
    data_FT = dataset[['Date', 'Close']]

    close_fft = np.fft.fft(np.asarray(data_FT['Close'].tolist()))
    fft_df = pd.DataFrame({'fft': close_fft})
    fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
    fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))

    fft_list = np.asarray(fft_df['fft'].tolist())
    fft_com_df = pd.DataFrame()
    for num_ in [3, 6, 9]:
        fft_list_m10 = np.copy(fft_list);
        fft_list_m10[num_:-num_] = 0
        fft_ = np.fft.ifft(fft_list_m10)
        fft_com = pd.DataFrame({'fft': fft_})
        fft_com['absolute of ' + str(num_) + ' comp'] = fft_com['fft'].apply(lambda x: np.abs(x))
        fft_com['angle of ' + str(num_) + ' comp'] = fft_com['fft'].apply(lambda x: np.angle(x))
        fft_com = fft_com.drop(columns='fft')
        fft_com_df = pd.concat([fft_com_df, fft_com], axis=1)

    return fft_com_df

# %%
# Calculate technical indicators
T_df = get_technical_indicators(df)

# %%
T_df.head(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-02-03  1100.670044  1102.719971  1093.969971  1097.280029  1097.280029
# 2010-02-04  1097.250000  1097.250000  1062.780029  1063.109985  1063.109985
# 2010-02-05  1064.119995  1067.130005  1044.500000  1066.189941  1066.189941
# 2010-02-08  1065.510010  1071.199951  1056.510010  1056.739990  1056.739990
# 2010-02-09  1060.060059  1079.280029  1060.060059  1070.520020  1070.520020
# 2010-02-10  1069.680054  1073.670044  1059.339966  1068.130005  1068.130005
# 2010-02-12  1075.949951  1077.810059  1062.969971  1075.510010  1075.510010
# 2010-02-16  1079.130005  1095.670044  1079.130005  1094.869995  1094.869995
# 2010-02-17  1096.140015  1101.030029  1094.719971  1099.510010  1099.510010
# 2010-02-18  1099.030029  1108.239990  1097.479980  1106.750000  1106.750000
#
#                   Volume       BZ=F   DX-Y.NYB  EURUSD=X         GC=F  ...  \
# Date                                                                   ...
# 2010-02-03  4.285450e+09  75.919998  79.370003  1.390105  1111.400024  ...
# 2010-02-04  5.859690e+09  72.129997  79.919998  1.374495  1062.400024  ...
# 2010-02-05  6.438900e+09  69.589996  80.440002  1.368008  1052.199951  ...
# 2010-02-08  4.089820e+09  70.110001  80.300003  1.365467  1065.699951  ...
# 2010-02-09  5.114260e+09  72.129997  79.860001  1.378208  1076.699951  ...
# 2010-02-10  4.251450e+09  72.540001  80.029999  1.375327  1075.800049  ...
# 2010-02-12  4.160680e+09  72.900002  80.320000  1.363494  1089.500000  ...
# 2010-02-16  4.080770e+09  75.680000  79.699997  1.376709  1119.300049  ...
# 2010-02-17  4.259230e+09  76.269997  80.379997  1.360692  1119.500000  ...
# 2010-02-18  3.878620e+09  77.779999  80.400002  1.346149  1118.000000  ...
#
#                    ^N225       ^VIX          MA7         MA21      MACD  \
# Date
# 2010-02-03  10404.330078  21.600000  1091.122855  1118.612380 -0.874828
# 2010-02-04  10355.980469  26.080000  1086.971418  1115.284761 -3.072480
# 2010-02-05  10057.089844  26.110001  1082.498553  1111.935710 -0.225519
# 2010-02-08   9951.820312  26.510000  1078.528547  1108.107137  0.548875
# 2010-02-09   9932.900391  26.000000  1078.049979  1104.718093  0.944976
# 2010-02-10   9963.990234  25.400000  1075.041417  1101.058570  1.806910
# 2010-02-12  10092.190430  22.730000  1071.068569  1098.167620  2.389373
# 2010-02-16  10034.250000  22.250000  1070.724278  1095.748093  1.668083
# 2010-02-17  10306.830078  21.719999  1075.924282  1093.417143  0.635069
# 2010-02-18  10335.690430  20.629999  1081.718576  1092.022856 -0.712896
#
#                  20SD   upper_band   lower_band          EMA  logmomentum
# Date
# 2010-02-03  25.711726  1170.035832  1067.188929  1097.336610     6.999678
# 2010-02-04  28.046576  1171.377914  1059.191608  1074.518860     6.968013
# 2010-02-05  29.447445  1170.830599  1053.040821  1068.966248     6.970908
# 2010-02-08  30.832490  1169.772116  1046.442158  1060.815409     6.961997
# 2010-02-09  30.425162  1165.568417  1043.867770  1067.285149     6.974965
# 2010-02-10  30.286773  1161.632116  1040.485025  1067.848386     6.972728
# 2010-02-12  28.651459  1155.470539  1040.864701  1072.956135     6.979620
# 2010-02-16  25.834043  1147.416180  1044.080007  1087.565375     6.997477
# 2010-02-17  23.855802  1141.128747  1045.705540  1095.528465     7.001710
# 2010-02-18  19.845650  1131.714156  1052.331556  1103.009488     7.008279
#
# [10 rows x 26 columns]

# %%
T_df.shape
# Out:
# (3095, 26)

# %%
T_df = T_df.dropna()
T_df.shape
# Out:
# (3075, 26)

# %%
len(T_df)
# Out:
# 3075

# %%
FE_df = T_df

# %%
len(FE_df)
# Out:
# 3075

# %% [markdown]
# # 3. Data preparation

# %% [markdown]
# ## 3.1. Data split

# %%
data_training = FE_df[FE_df.index < '2020-12-31'].copy()
data_training.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-02-03  1100.670044  1102.719971  1093.969971  1097.280029  1097.280029
# 2010-02-04  1097.250000  1097.250000  1062.780029  1063.109985  1063.109985
# 2010-02-05  1064.119995  1067.130005  1044.500000  1066.189941  1066.189941
# 2010-02-08  1065.510010  1071.199951  1056.510010  1056.739990  1056.739990
# 2010-02-09  1060.060059  1079.280029  1060.060059  1070.520020  1070.520020
#
#                   Volume       BZ=F   DX-Y.NYB  EURUSD=X         GC=F  ...  \
# Date                                                                   ...
# 2010-02-03  4.285450e+09  75.919998  79.370003  1.390105  1111.400024  ...
# 2010-02-04  5.859690e+09  72.129997  79.919998  1.374495  1062.400024  ...
# 2010-02-05  6.438900e+09  69.589996  80.440002  1.368008  1052.199951  ...
# 2010-02-08  4.089820e+09  70.110001  80.300003  1.365467  1065.699951  ...
# 2010-02-09  5.114260e+09  72.129997  79.860001  1.378208  1076.699951  ...
#
#                    ^N225       ^VIX          MA7         MA21      MACD  \
# Date
# 2010-02-03  10404.330078  21.600000  1091.122855  1118.612380 -0.874828
# 2010-02-04  10355.980469  26.080000  1086.971418  1115.284761 -3.072480
# 2010-02-05  10057.089844  26.110001  1082.498553  1111.935710 -0.225519
# 2010-02-08   9951.820312  26.510000  1078.528547  1108.107137  0.548875
# 2010-02-09   9932.900391  26.000000  1078.049979  1104.718093  0.944976
#
#                  20SD   upper_band   lower_band          EMA  logmomentum
# Date
# 2010-02-03  25.711726  1170.035832  1067.188929  1097.336610     6.999678
# 2010-02-04  28.046576  1171.377914  1059.191608  1074.518860     6.968013
# 2010-02-05  29.447445  1170.830599  1053.040821  1068.966248     6.970908
# 2010-02-08  30.832490  1169.772116  1046.442158  1060.815409     6.961997
# 2010-02-09  30.425162  1165.568417  1043.867770  1067.285149     6.974965
#
# [5 rows x 26 columns]

# %%
data_testing = FE_df[FE_df.index >= '2020-12-31'].copy()
data_testing.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-01-04  3764.610107  3769.989990  3662.709961  3700.649902  3700.649902
# 2021-01-05  3698.020020  3737.830078  3695.070068  3726.860107  3726.860107
# 2021-01-06  3712.199951  3783.040039  3705.340088  3748.139893  3748.139893
# 2021-01-07  3764.709961  3811.550049  3764.709961  3803.790039  3803.790039
# 2021-01-08  3815.050049  3826.689941  3783.600098  3824.679932  3824.679932
#
#                   Volume       BZ=F   DX-Y.NYB  EURUSD=X         GC=F  ...  \
# Date                                                                   ...
# 2021-01-04  5.015000e+09  51.090000  89.879997  1.225070  1944.699951  ...
# 2021-01-05  4.591020e+09  53.599998  89.440002  1.225160  1952.699951  ...
# 2021-01-06  6.064110e+09  54.299999  89.529999  1.230027  1906.900024  ...
# 2021-01-07  5.099160e+09  54.380001  89.830002  1.234111  1912.300049  ...
# 2021-01-08  4.773040e+09  55.990002  90.099998  1.227144  1834.099976  ...
#
#                    ^N225       ^VIX          MA7         MA21       MACD  \
# Date
# 2021-01-04  27258.380859  26.969999  3710.935686  3684.557141 -63.160595
# 2021-01-05  27158.630859  25.340000  3711.561419  3688.771903 -60.583559
# 2021-01-06  27055.939453  25.070000  3717.094273  3694.796189 -63.378215
# 2021-01-07  27490.130859  22.370001  3732.647147  3701.526669 -65.507146
# 2021-01-08  28139.029297  21.559999  3751.885707  3708.939523 -67.298839
#
#                  20SD   upper_band   lower_band          EMA  logmomentum
# Date
# 2021-01-04  27.718356  3739.993853  3629.120428  3709.311603     8.215993
# 2021-01-05  24.481606  3737.735115  3639.808690  3721.010606     8.223053
# 2021-01-06  26.434494  3747.665177  3641.927201  3739.096797     8.228748
# 2021-01-07  34.903893  3771.334456  3631.718882  3782.225625     8.243490
# 2021-01-08  43.128555  3795.196633  3622.682413  3810.528496     8.248969
#
# [5 rows x 26 columns]

# %%
data_training.shape, data_testing.shape
# Out:
# ((2472, 26), (603, 26))

# %%
scalar = MinMaxScaler()

data_training_scaled = scalar.fit_transform(data_training)
print(data_training_scaled.shape)
# Out:
# (2472, 26)

# %%
# window size is 60, nb sample = 1935 (data_training.shape[0]), y_train is price (first colonne, 0)

# %%
X_train, y_train = rnn_3D_data(data_training_scaled, window_size=60, y_pos=4)

# %%
X_train.shape, y_train.shape
# Out:
# ((2412, 60, 26), (2412,))

# %%
# add the winodw before test data
data_test = pd.concat([data_training.tail(60), data_testing], ignore_index=True)
data_test_scaled = scalar.fit_transform(data_test)

X_test, y_test = rnn_3D_data(data_test_scaled, window_size=60, y_pos=4)
X_test.shape, y_test.shape
# Out:
# ((603, 60, 26), (603,))

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, activation = 'relu', input_shape = (X_train.shape[1], X_train.shape[2])))
regressor.add(Dropout(0.5))

#regressor.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
#regressor.add(Dropout(0.3))

#regressor.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
#regressor.add(Dropout(0.4))

#regressor.add(LSTM(units = 120, activation = 'relu'))
#regressor.add(Dropout(0.5))

regressor.add(Dense(units = 1))

# %%
regressor.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 50)                15400
#
#  dropout_5 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 15,451
# Trainable params: 15,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
history = regressor.fit(X_train, y_train, epochs=50, batch_size = 64,shuffle=False, validation_data=(X_test, y_test),verbose=1)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 2s 29ms/step - loss: 0.0246 - val_loss: 0.0035
# Epoch 2/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0247 - val_loss: 0.0051
# Epoch 3/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0245 - val_loss: 0.0136
# Epoch 4/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0218 - val_loss: 0.0082
# Epoch 5/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0150 - val_loss: 0.0043
# Epoch 6/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0180 - val_loss: 0.0107
# Epoch 7/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0146 - val_loss: 0.0040
# Epoch 8/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0141 - val_loss: 0.0060
# Epoch 9/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0121 - val_loss: 0.0045
# Epoch 10/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0113 - val_loss: 0.0067
# Epoch 11/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0110 - val_loss: 0.0066
# Epoch 12/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0101 - val_loss: 0.0074
# Epoch 13/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0098 - val_loss: 0.0055
# Epoch 14/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0107 - val_loss: 0.0073
# Epoch 15/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0093 - val_loss: 0.0107
# Epoch 16/50
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0094 - val_loss: 0.0039
# Epoch 17/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0091 - val_loss: 0.0073
# Epoch 18/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0079 - val_loss: 0.0044
# Epoch 19/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0046
# Epoch 20/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0073 - val_loss: 0.0047
# Epoch 21/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0067 - val_loss: 0.0028
# Epoch 22/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0068 - val_loss: 0.0097
# Epoch 23/50
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0070 - val_loss: 0.0043
# Epoch 24/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 25/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 26/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0068 - val_loss: 0.0040
# Epoch 27/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0060 - val_loss: 0.0030
# Epoch 28/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0064 - val_loss: 0.0035
# Epoch 29/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0062 - val_loss: 0.0026
# Epoch 30/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0063 - val_loss: 0.0029
# Epoch 31/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0061 - val_loss: 0.0025
# Epoch 32/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 33/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0064 - val_loss: 0.0041
# Epoch 34/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0058 - val_loss: 0.0027
# Epoch 35/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 36/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0066 - val_loss: 0.0029
# Epoch 37/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0065 - val_loss: 0.0026
# Epoch 38/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 39/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0058 - val_loss: 0.0028
# Epoch 40/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0067 - val_loss: 0.0037
# Epoch 41/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0057 - val_loss: 0.0043
# Epoch 42/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0062 - val_loss: 0.0029
# Epoch 43/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 44/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0061 - val_loss: 0.0030
# Epoch 45/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0079 - val_loss: 0.0062
# Epoch 46/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0062 - val_loss: 0.0032
# Epoch 47/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0069 - val_loss: 0.0032
# Epoch 48/50
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0057 - val_loss: 0.0027
# Epoch 49/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0060 - val_loss: 0.0038
# Epoch 50/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0059 - val_loss: 0.0047

# %%
# Plotting training and validation loss over epochs
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.yscale('log')  # Set y-axis to logarithmic scale
plt.legend()
plt.show()

# %%
rmse = lstm_mse_rsme(history)

# %%
y_pred = regressor.predict(X_test)
# Out:
# 19/19 [==============================] - 0s 7ms/step

# %%
y_pred[:3]
# Out:
# array([[0.28435838],
#        [0.27901545],
#        [0.27804062]], dtype=float32)

# %%
scale = 1/scalar.scale_[0]

# %%
y_pred = y_pred*scale
y_test = y_test*scale

# %%
y_pred[:3]
# Out:
# array([[434.3119 ],
#        [426.15143],
#        [424.6625 ]], dtype=float32)

# %%
# Visualising the results
plt.figure(figsize=(28,12))
plt.plot(y_test, color = 'red', label = 'Real SP500 Price')
plt.plot(y_pred, color = 'blue', label = 'Predicted SP500 Price')
plt.title('SP500 Price Prediction-After 50 epochs and Batch Size=64')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
