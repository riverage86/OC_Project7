# %% [raw]
# LSTM M3:   M0 + rmprop

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
from datetime import date
import math
import pandas_datareader as web
import yfinance as yf
import time  # Import the time module
import os  # Import the os module
from sklearn.model_selection import TimeSeriesSplit

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from pathlib import Path

# %%
# reshape 2D dataset (samples + features) en 3D (samples/time step + features + séquence) 
# en ajoutant la dimension fenêtre/séquence (longueur est window_size) N, pour prédire N+1. 
# y_pos est la position de colonnes du target. Normalament la prémière colonne
# dataset.shape[0] est le nombre des échantillons
def rnn_3D_data(dataset, window_size, y_pos=0): 
    X = []
    y = []
    for i in range(window_size, dataset.shape[0]):
        X.append(dataset[i-window_size: i])
        y.append(dataset[i, y_pos])
    X, y = np.array(X), np.array(y)
    return X, y

# %%
def data_retrieve(stock, start_date, end_date): 

# Define the list of tickers for the stocks you want to fetch data for
    tickers = [stock]

    # Define the list of stock indices and other features
    indices = ['^GSPC', '^DJI', '^IXIC', 'DX-Y.NYB', '^GDAXI', '^FTSE', '^N225', '^VIX']
    commodities = ['GC=F', 'BZ=F']
    forex = ['EURUSD=X', 'JPY=X']

    symbols = indices + commodities + forex
    # Fetch the historical data using yfinance for tickers (OHLC and Volume)
    ticker_data = yf.download(tickers, start=start_date, end=end_date)

    # Fetch the historical data using yfinance for indices and commodities (Close Price)
    close_data = yf.download(symbols, start=start_date, end=end_date)['Adj Close']

# Concatenate the close_data with the ticker_data to include Close Price for all symbols
    all_data = pd.concat([ticker_data, close_data], axis=1)

# Print the data
    return all_data

# %%
# Définir le modèle avec cycle scaling, reshing, compile, entrainement
def LSTM_M3(df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout):

    scalar = MinMaxScaler()

    data_training_scaled = scalar.fit_transform(data_training)
    X_train, y_train = rnn_3D_data(data_training_scaled, window_size=win_size, y_pos=4)
    
    # add the winodw before test data
    data_test = pd.concat([data_training.tail(win_size), data_testing], ignore_index=True)
    data_test_scaled = scalar.fit_transform(data_test)
    X_test, y_test = rnn_3D_data(data_test_scaled, window_size=win_size, y_pos=4)
    
    y_scaler_train = MinMaxScaler()
    y_scaler_train.fit(data_training["Close"].values.reshape(-1, 1))
    y_scaler_test = MinMaxScaler()
    y_scaler_test.fit(data_test["Close"].values.reshape(-1, 1))
    
    model = Sequential()

    model.add(LSTM(units = num_cell, activation = 'relu', input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units = 1))

    start_time = time.time()
    # Compiling the RNN
    model.compile(optimizer = 'rmsprop', loss = 'mean_squared_error')
    
    rnn_path = (results_path / 'lstm_M3.h5').as_posix()
    checkpointer = ModelCheckpoint(filepath=rnn_path,
                               verbose=1,
                               monitor='val_loss',
                               save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=20,
                              restore_best_weights=True)
    
    lstm_training = model.fit(X_train, y_train, epochs=num_epoch, batch_size = batch_size,\
                        shuffle=True, validation_data=(X_test, y_test),\
                        callbacks=[early_stopping, checkpointer],
                        verbose=1)     
    
    end_time = time.time()
    execution_time = end_time - start_time   
    
    # evaluer le modèle
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(lstm_training.history).pow(.5)
    loss_history.index += 1
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    
    resultat = ['LSTM_M3',win_size,num_cell, num_epoch, batch_size, dropout, round(best_rmse, 4), round(execution_time, 0)]
    return model, resultat, lstm_training, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test

# %% [markdown]
# # Parameters

# %%
win_size = 60
num_epoch = 100
num_cell = 50
batch_size = 64
dropout = 0.5
split_date = '2020-12-31'
# pour stocker les modèles 
results_path = Path('models', 'M3')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# # 1. Raw data collection

# %%
start_date = datetime.datetime(2010, 1, 2)
end_date = datetime.datetime.today()

# %%
raw_data = yf.download('^GSPC', start=start_date, end=end_date)
raw_data.to_parquet('sp500_data.parquet')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
raw_data.to_parquet('sp500_data.parquet')

# %%
data = pd.read_parquet('sp500_data.parquet')

# %%
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('There are {} number of days in the dataset.'.format(data.shape[0]))
# Out:
# There are 3430 number of days in the dataset.

# %%
plt.figure(figsize=(28, 12))#, dpi=100)
plt.plot(data.index, data['Adj Close'], label='SP500')
plt.xlabel('Date')
plt.ylabel('Rs')
plt.title('sp500')
plt.legend()
plt.show()

# %%
df = data.copy()
df = df.dropna()
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('Total dataset has {} samples, and {} features.'.format(df.shape[0], \
                                                              df.shape[1]))
# Out:
# Total dataset has 3430 samples, and 6 features.

# %% [markdown]
# # 2. Feature engineering

# %%
FE_df = df

# %%
len(FE_df)
# Out:
# 3430

# %% [markdown]
# # 3. Modèle processing

# %% [markdown]
# ## 3.1. Data split

# %%
data_training = FE_df[FE_df.index < split_date].copy()
data_training.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
y_train_real_all = data_training["Close"].values.reshape(-1, 1)

# %%
#remove the first win_size row which are without prediction
y_train_real = y_train_real_all[win_size:]

# %%
data_testing = FE_df[FE_df.index >= split_date].copy()
data_testing.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
# 2021-01-04  3764.610107  3769.989990  3662.709961  3700.649902  3700.649902
# 2021-01-05  3698.020020  3737.830078  3695.070068  3726.860107  3726.860107
# 2021-01-06  3712.199951  3783.040039  3705.340088  3748.139893  3748.139893
# 2021-01-07  3764.709961  3811.550049  3764.709961  3803.790039  3803.790039
#
#                 Volume
# Date
# 2020-12-31  3179040000
# 2021-01-04  5015000000
# 2021-01-05  4591020000
# 2021-01-06  6064110000
# 2021-01-07  5099160000

# %%
y_test_real = data_testing["Close"].values.reshape(-1, 1)

# %% [raw]
# Normalization: MinMaxScaler transforms your data to a specific range, typically between 0 and 1. This is especially useful when you have features with different scales, as it ensures that all features are on a similar scale. This can be important for algorithms that are sensitive to the scale of features, like gradient-based optimization algorithms.
# Applied to all features.

# %%
#scalar = MinMaxScaler()

#data_training_scaled = scalar.fit_transform(data_training)

# %% [markdown]
# ## 3.2 Data scaling, reshaping, Model

# %%
current_datetime = datetime.datetime.today()
formatted_datetime = current_datetime.strftime('%Y-%m-%d %H:%M')

# %%
lstm_model, resultat, model_history, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test = \
LSTM_M3(FE_df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout)
# Out:
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0433
# Epoch 1: val_loss improved from inf to 0.01605, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 3s 31ms/step - loss: 0.0433 - val_loss: 0.0160
# Epoch 2/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 2: val_loss improved from 0.01605 to 0.01124, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0147 - val_loss: 0.0112
# Epoch 3/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0121
# Epoch 3: val_loss improved from 0.01124 to 0.00695, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0122 - val_loss: 0.0070
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 4: val_loss improved from 0.00695 to 0.00362, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0104 - val_loss: 0.0036
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 5: val_loss improved from 0.00362 to 0.00353, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0090 - val_loss: 0.0035
# Epoch 6/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 6: val_loss did not improve from 0.00353
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0083 - val_loss: 0.0045
# Epoch 7/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0079
# Epoch 7: val_loss did not improve from 0.00353
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0078 - val_loss: 0.0047
# Epoch 8/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 8: val_loss did not improve from 0.00353
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0065 - val_loss: 0.0039
# Epoch 9/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 9: val_loss improved from 0.00353 to 0.00312, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0065 - val_loss: 0.0031
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 10: val_loss improved from 0.00312 to 0.00296, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0061 - val_loss: 0.0030
# Epoch 11/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 11: val_loss did not improve from 0.00296
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 12/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 12: val_loss did not improve from 0.00296
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 13/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0053
# Epoch 13: val_loss improved from 0.00296 to 0.00293, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 14/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 14: val_loss improved from 0.00293 to 0.00278, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 15/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0046
# Epoch 15: val_loss did not improve from 0.00278
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 16/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 16: val_loss did not improve from 0.00278
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0044 - val_loss: 0.0028
# Epoch 17/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0042
# Epoch 17: val_loss did not improve from 0.00278
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0042 - val_loss: 0.0089
# Epoch 18/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 18: val_loss did not improve from 0.00278
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 19/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 19: val_loss improved from 0.00278 to 0.00270, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0044 - val_loss: 0.0027
# Epoch 20/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0042
# Epoch 20: val_loss did not improve from 0.00270
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 21/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 21: val_loss did not improve from 0.00270
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 22/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 22: val_loss improved from 0.00270 to 0.00264, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 23/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 23: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 24/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 24: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0042 - val_loss: 0.0031
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 25: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 26: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 27/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 27: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0039 - val_loss: 0.0029
# Epoch 28/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 28: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 29/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 29: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 30/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 30: val_loss did not improve from 0.00264
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 31/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 31: val_loss improved from 0.00264 to 0.00249, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 32/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 32: val_loss did not improve from 0.00249
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 33/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 33: val_loss did not improve from 0.00249
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 34/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 34: val_loss improved from 0.00249 to 0.00240, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 35/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 35: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 36/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 36: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 37/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 37: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 38/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 38: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 39/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 39: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 40/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 40: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 41/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 41: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 42/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 42: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 43/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 43: val_loss did not improve from 0.00240
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 44/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 44: val_loss improved from 0.00240 to 0.00233, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 45/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 45: val_loss did not improve from 0.00233
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0050
# Epoch 46/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 46: val_loss did not improve from 0.00233
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 47/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 47: val_loss improved from 0.00233 to 0.00231, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 48/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 48: val_loss did not improve from 0.00231
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 49/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 49: val_loss did not improve from 0.00231
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 50/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 50: val_loss did not improve from 0.00231
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 51/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 51: val_loss did not improve from 0.00231
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 52/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 52: val_loss improved from 0.00231 to 0.00219, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 53/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 53: val_loss did not improve from 0.00219
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 54/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 54: val_loss improved from 0.00219 to 0.00214, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 55/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 55: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 56/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 56: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 57/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 57: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 58/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 58: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 59/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 59: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 60/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 60: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 61/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0039
# Epoch 61: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 62/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 62: val_loss did not improve from 0.00214
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 63/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 63: val_loss improved from 0.00214 to 0.00211, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 64/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 64: val_loss improved from 0.00211 to 0.00206, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 65/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 65: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 66/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 66: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 67/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 67: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 68/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 68: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 69/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 69: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 70/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 70: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 71/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 71: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 72/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 72: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 73/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 73: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 74/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 74: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 75/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 75: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 76/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 76: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 77/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 77: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 78/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 78: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 79/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 79: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 80/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 80: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 81/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 81: val_loss did not improve from 0.00206
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 82/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 82: val_loss improved from 0.00206 to 0.00199, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 83/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 83: val_loss improved from 0.00199 to 0.00197, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 84/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 84: val_loss did not improve from 0.00197
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 85/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 85: val_loss did not improve from 0.00197
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 86/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 86: val_loss did not improve from 0.00197
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 87/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 87: val_loss did not improve from 0.00197
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 88/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 88: val_loss did not improve from 0.00197
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 89/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 89: val_loss did not improve from 0.00197
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0036 - val_loss: 0.0054
# Epoch 90/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 90: val_loss improved from 0.00197 to 0.00197, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 91/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 91: val_loss improved from 0.00197 to 0.00192, saving model to models/M3\lstm_M3.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 92/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 92: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 93/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 93: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 94/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 94: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 95/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 95: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 96/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 96: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 97/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 97: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 98/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0036
# Epoch 98: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 99/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 99: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 100/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 100: val_loss did not improve from 0.00192
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0021

# %%
resultat.insert(0, formatted_datetime)

# %% [markdown]
# # 4. Evaluation performance

# %% [markdown]
# ## 4.1. Scaled performance

# %%
def lstm_scaled_perfomance(model_history, start_epoch=1):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(start_epoch, start_epoch + len(model_history.history['loss']))
    
    # loss, val_loss 
    axs[0].plot(epochs, model_history.history['loss'], label='Training Loss')
    axs[0].plot(epochs, model_history.history['val_loss'],  label='Validation Loss')
    axs[0].set_title('Model Loss')
    axs[0].set_ylabel('Loss')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validation'], loc='best')
    
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(model_history.history).pow(.5)
    loss_history.index += 1    
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    best_epoch = loss_history.val_loss.idxmin()    
    title = f'Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
    loss_history.columns=['Training RMSE', 'Validation RMSE']
    
    loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=axs[1])    
    axs[1].axvline(best_epoch, ls='--', lw=1, c='k')
    
    sns.despine()
    fig.tight_layout()    
    plt.show()
    return best_rmse, best_epoch

# %%
best_rmse, best_epoch = lstm_scaled_perfomance(model_history)

# %%
y_train_predict_scaled = lstm_model.predict(X_train)
y_test_predict_scaled = lstm_model.predict(X_test)
# Out:
# 85/85 [==============================] - 1s 6ms/step
# 21/21 [==============================] - 0s 6ms/step

# %% [raw]
# Spearman's rank correlation coefficient, often denoted as ρ (rho), is a statistical measure that quantifies the strength and direction of a monotonic relationship between two variables. Instead of considering the actual values of the variables, it considers their ranks.
#
# The Spearman's rank correlation coefficient can take values between -1 and 1:
#
# ρ = 1: Perfect monotonic increasing relationship.
# ρ = -1: Perfect monotonic decreasing relationship.
# ρ = 0: No monotonic relationship.

# %%
from scipy.stats import spearmanr
train_ic = spearmanr(y_train, y_train_predict_scaled)[0]
test_ic = spearmanr(y_test, y_test_predict_scaled)[0]
print(f'Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}')
# Out:
# Train IC: 0.9982 | Test IC: 0.9718

# %%
resultat.extend([round(train_ic, 4), round(test_ic,4)])

# %%
import matplotlib.pyplot as plt

# Plotting the train and test predictions against actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_predict_scaled, label='Train Predictions')
plt.scatter(y_test, y_test_predict_scaled, label='Test Predictions')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Spearman rank correlation (IC)')
plt.legend()
plt.show()

# %% [markdown]
# ## 4.2. Rescaled performance

# %%
def lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    axs[0].plot(y_train_real, color = 'red', label = 'Real SP500 Price')
    axs[0].plot(y_train_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[0].set_title('SP500 Train Price Prediction')
    axs[0].set_ylabel('Price')
    axs[0].set_xlabel('Time')
    axs[0].legend(['Real', 'Predict'], loc='best')

    axs[1].plot(y_test_real, color = 'red', label = 'Real SP500 Price')
    axs[1].plot(y_test_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[1].set_title('SP500 Test Price Prediction')
    axs[1].set_ylabel('Price')
    axs[1].set_xlabel('Time')
    axs[1].legend(['Real', 'Predict'], loc='best')

    plt.legend()  
    plt.show()
    return

# %%
y_test_predict = y_scaler_test.inverse_transform(y_test_predict_scaled)
y_train_predict = y_scaler_train.inverse_transform(y_train_predict_scaled)

# %%
lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict)

# %%
train_rmse_scaled = np.sqrt(lstm_model.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm_model.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE: {train_rmse_scaled:.4f} | Test RMSE: {test_rmse_scaled:.4f}')
# Out:
# Train RMSE: 0.0166 | Test RMSE: 0.0463

# %%
resultat.extend([round(train_rmse_scaled, 4), round(test_rmse_scaled,4)])

# %%
train_rmse = np.sqrt(mean_squared_error(y_train_predict, y_train_real))
test_rmse = np.sqrt(mean_squared_error(y_test_predict, y_test_real))
f'Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}'
# Out:
# 'Train RMSE: 44.91 | Test RMSE: 70.74'

# %%
resultat.extend([round(train_rmse, 2), round(test_rmse,2)])

# %%
models_performance = pd.read_csv('models_performance.csv', index_col=[0])
models_performance.loc[len(models_performance)] = resultat
models_performance.to_csv('models_performance.csv')

# %%
def real_predict_dist(y_train_real, y_train_predict, y_test_real, y_test_predict):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    diff_train = y_train_predict - y_train_real
    diff_test = y_test_predict - y_test_real
    
# Création de l'histogramme de la distribution
    axs[0].hist(diff_train, bins=20, edgecolor='black')
# Ajout de labels et de titres
    axs[0].set_xlabel('Différence entre y_train_predict et y_train_real')
    axs[0].set_ylabel('Fréquence')
    axs[0].set_title('Distribution différence train')

    # Création de l'histogramme de la distribution
    axs[1].hist(diff_test, bins=20, edgecolor='black')
# Ajout de labels et de titres
    axs[1].set_xlabel('Différence entre y_test_predict et y_test_real')
    axs[1].set_ylabel('Fréquence')
    axs[1].set_title('Distribution différence test')

    plt.show()
    return

# %%
real_predict_dist(y_train_real, y_train_predict, y_test_real, y_test_predict)
