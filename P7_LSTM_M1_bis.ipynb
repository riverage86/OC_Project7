# %% [raw]
# LSTM M1 :  M0 + Technical indicators and raw data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
from datetime import date
import math
import pandas_datareader as web
import yfinance as yf
import time  # Import the time module
import os  # Import the os module
from sklearn.model_selection import TimeSeriesSplit

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from pathlib import Path

# %%
# reshape 2D dataset (samples + features) en 3D (samples/time step + features + séquence) 
# en ajoutant la dimension fenêtre/séquence (longueur est window_size) N, pour prédire N+1. 
# y_pos est la position de colonnes du target. Normalament la prémière colonne
# dataset.shape[0] est le nombre des échantillons
def rnn_3D_data(dataset, window_size, y_pos=0): 
    X = []
    y = []
    for i in range(window_size, dataset.shape[0]):
        X.append(dataset[i-window_size: i])
        y.append(dataset[i, y_pos])
    X, y = np.array(X), np.array(y)
    return X, y

# %%
def data_retrieve(stock, start_date, end_date): 

# Define the list of tickers for the stocks you want to fetch data for
    tickers = [stock]

    # Define the list of stock indices and other features
    indices = ['^GSPC', '^DJI', '^IXIC', 'DX-Y.NYB', '^GDAXI', '^FTSE', '^N225', '^VIX']
    commodities = ['GC=F', 'BZ=F']
    forex = ['EURUSD=X', 'JPY=X']

    symbols = indices + commodities + forex
    # Fetch the historical data using yfinance for tickers (OHLC and Volume)
    ticker_data = yf.download(tickers, start=start_date, end=end_date)

    # Fetch the historical data using yfinance for indices and commodities (Close Price)
    close_data = yf.download(symbols, start=start_date, end=end_date)['Adj Close']

# Concatenate the close_data with the ticker_data to include Close Price for all symbols
    all_data = pd.concat([ticker_data, close_data], axis=1)

# Print the data
    return all_data

# %%
# Définir le modèle avec cycle scaling, reshing, compile, entrainement
def LSTM_M1(df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout):

    scalar = MinMaxScaler()

    data_training_scaled = scalar.fit_transform(data_training)
    X_train, y_train = rnn_3D_data(data_training_scaled, window_size=win_size, y_pos=4)
    
    # add the winodw before test data
    data_test = pd.concat([data_training.tail(win_size), data_testing], ignore_index=True)
    data_test_scaled = scalar.fit_transform(data_test)
    X_test, y_test = rnn_3D_data(data_test_scaled, window_size=win_size, y_pos=4)
    
    y_scaler_train = MinMaxScaler()
    y_scaler_train.fit(data_training["Close"].values.reshape(-1, 1))
    y_scaler_test = MinMaxScaler()
    y_scaler_test.fit(data_test["Close"].values.reshape(-1, 1))
    
    model = Sequential()

    model.add(LSTM(units = num_cell, activation = 'relu', input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units = 1))

    start_time = time.time()
    # Compiling the RNN
    model.compile(optimizer = 'adam', loss = 'mean_squared_error')
    
    rnn_path = (results_path / 'lstm_M1.h5').as_posix()
    checkpointer = ModelCheckpoint(filepath=rnn_path,
                               verbose=1,
                               monitor='val_loss',
                               save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=20,
                              restore_best_weights=True)
    
    lstm_training = model.fit(X_train, y_train, epochs=num_epoch, batch_size = batch_size,\
                        shuffle=True, validation_data=(X_test, y_test),\
                        callbacks=[early_stopping, checkpointer],
                        verbose=1)     
    
    end_time = time.time()
    execution_time = end_time - start_time   
    
    # evaluer le modèle
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(lstm_training.history).pow(.5)
    loss_history.index += 1
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    
    resultat = ['M1',win_size,num_cell, num_epoch, batch_size, dropout, round(best_rmse, 4), round(execution_time, 0)]
    return model, resultat, lstm_training, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test

# %% [markdown]
# # Parameters

# %%
win_size = 60
num_epoch = 100
num_cell = 50
batch_size = 64
dropout = 0.5
split_date = '2020-12-31'
# pour stocker les modèles 
results_path = Path('models', 'M1')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# # 1. Raw data collection

# %%
start_date = datetime.datetime(2010, 1, 2)
end_date = datetime.datetime.today()

# %%
raw_data = yf.download('^GSPC', start=start_date, end=end_date)
raw_data.to_parquet('sp500_data.parquet')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
raw_data.to_parquet('sp500_data.parquet')

# %%
data = pd.read_parquet('sp500_data.parquet')

# %%
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('There are {} number of days in the dataset.'.format(data.shape[0]))
# Out:
# There are 3430 number of days in the dataset.

# %%
plt.figure(figsize=(28, 12))#, dpi=100)
plt.plot(data.index, data['Adj Close'], label='SP500')
plt.xlabel('Date')
plt.ylabel('Rs')
plt.title('sp500')
plt.legend()
plt.show()

# %%
df = data.copy()
df = df.dropna()
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('Total dataset has {} samples, and {} features.'.format(df.shape[0], \
                                                              df.shape[1]))
# Out:
# Total dataset has 3430 samples, and 6 features.

# %% [markdown]
# # 2. Feature engineering

# %%
# Calculate technical indicators
def get_technical_indicators(data):
    # Create 7 and 21 days Moving Average
    data['MA7'] = data.iloc[:,4].rolling(window=7).mean()
    data['MA21'] = data.iloc[:,4].rolling(window=21).mean()

    # Create MACD
    data['MACD'] = data.iloc[:,4].ewm(span=26).mean() - data.iloc[:,1].ewm(span=12,adjust=False).mean()

    # Create Bollinger Bands
    data['20SD'] = data.iloc[:, 4].rolling(20).std()
    data['upper_band'] = data['MA21'] + (data['20SD'] * 2)
    data['lower_band'] = data['MA21'] - (data['20SD'] * 2)

    # Create Exponential moving average
    data['EMA'] = data.iloc[:,4].ewm(com=0.5).mean()

    # Create LogMomentum
    data['logmomentum'] = np.log(data.iloc[:,4] - 1)

    return data

# %%
# Getting the Fourier transform features,  applies the Fast Fourier Transform (FFT) on the 'Close' column of
# the input dataset and extracts various Fourier coefficients and their corresponding absolute values and angles,  
# these features can help identify recurring patterns or cyclic behavior in stock prices,
def get_fourier_transfer(dataset):
    # Get the columns for doing fourier
    data_FT = dataset[['Date', 'Close']]

    close_fft = np.fft.fft(np.asarray(data_FT['Close'].tolist()))
    fft_df = pd.DataFrame({'fft': close_fft})
    fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
    fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))

    fft_list = np.asarray(fft_df['fft'].tolist())
    fft_com_df = pd.DataFrame()
    for num_ in [3, 6, 9]:
        fft_list_m10 = np.copy(fft_list);
        fft_list_m10[num_:-num_] = 0
        fft_ = np.fft.ifft(fft_list_m10)
        fft_com = pd.DataFrame({'fft': fft_})
        fft_com['absolute of ' + str(num_) + ' comp'] = fft_com['fft'].apply(lambda x: np.abs(x))
        fft_com['angle of ' + str(num_) + ' comp'] = fft_com['fft'].apply(lambda x: np.angle(x))
        fft_com = fft_com.drop(columns='fft')
        fft_com_df = pd.concat([fft_com_df, fft_com], axis=1)

    return fft_com_df

# %%
# Calculate technical indicators
T_df = get_technical_indicators(df)
T_df = T_df.dropna()
T_df.shape
# Out:
# (3410, 14)

# %%
FE_df = T_df

# %%
len(FE_df)
# Out:
# 3410

# %% [markdown]
# # 3. Modèle processing

# %% [markdown]
# ## 3.1. Data split

# %%
data_training = FE_df[FE_df.index < split_date].copy()
data_training.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-02-02  1090.050049  1104.729980  1087.959961  1103.319946  1103.319946
# 2010-02-03  1100.670044  1102.719971  1093.969971  1097.280029  1097.280029
# 2010-02-04  1097.250000  1097.250000  1062.780029  1063.109985  1063.109985
# 2010-02-05  1064.119995  1067.130005  1044.500000  1066.189941  1066.189941
# 2010-02-08  1065.510010  1071.199951  1056.510010  1056.739990  1056.739990
#
#                 Volume          MA7         MA21      MACD       20SD  \
# Date
# 2010-02-02  4749540000  1091.051426  1120.979045 -0.372808  26.014538
# 2010-02-03  4285450000  1091.122855  1119.278570 -0.259626  26.212060
# 2010-02-04  5859690000  1086.971418  1115.782854 -2.434869  28.551512
# 2010-02-05  6438900000  1082.498553  1112.404279  0.415377  29.762753
# 2010-02-08  4089820000  1078.528547  1108.359044  1.194482  30.967057
#
#              upper_band   lower_band          EMA  logmomentum
# Date
# 2010-02-02  1173.008121  1068.949968  1097.449772     7.005172
# 2010-02-03  1171.702690  1066.854450  1097.336610     6.999678
# 2010-02-04  1172.885878  1058.679831  1074.518860     6.968013
# 2010-02-05  1171.929786  1052.878772  1068.966248     6.970908
# 2010-02-08  1170.293158  1046.424930  1060.815409     6.961997

# %%
y_train_real_all = data_training["Close"].values.reshape(-1, 1)

# %%
#remove the first win_size row which are without prediction
y_train_real = y_train_real_all[win_size:]

# %%
data_testing = FE_df[FE_df.index >= split_date].copy()
data_testing.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
# 2021-01-04  3764.610107  3769.989990  3662.709961  3700.649902  3700.649902
# 2021-01-05  3698.020020  3737.830078  3695.070068  3726.860107  3726.860107
# 2021-01-06  3712.199951  3783.040039  3705.340088  3748.139893  3748.139893
# 2021-01-07  3764.709961  3811.550049  3764.709961  3803.790039  3803.790039
#
#                 Volume          MA7         MA21       MACD       20SD  \
# Date
# 2020-12-31  3179040000  3718.691476  3696.874779 -50.372963  27.183853
# 2021-01-04  5015000000  3720.604318  3698.381441 -55.388451  26.150483
# 2021-01-05  4591020000  3725.868617  3701.245257 -52.587781  26.830160
# 2021-01-06  6064110000  3732.308594  3703.579532 -55.298346  28.672777
# 2021-01-07  5099160000  3742.084298  3708.904774 -57.453472  36.293619
#
#              upper_band   lower_band          EMA  logmomentum
# Date
# 2020-12-31  3751.242486  3642.507072  3747.362312     8.230862
# 2021-01-04  3750.682408  3646.080474  3716.220706     8.215993
# 2021-01-05  3754.905577  3647.584936  3723.313640     8.223053
# 2021-01-06  3760.925085  3646.233978  3739.864475     8.228748
# 2021-01-07  3781.492011  3636.317536  3782.481518     8.243490

# %%
y_test_real = data_testing["Close"].values.reshape(-1, 1)

# %% [raw]
# Normalization: MinMaxScaler transforms your data to a specific range, typically between 0 and 1. This is especially useful when you have features with different scales, as it ensures that all features are on a similar scale. This can be important for algorithms that are sensitive to the scale of features, like gradient-based optimization algorithms.
# Applied to all features.

# %%
#scalar = MinMaxScaler()

#data_training_scaled = scalar.fit_transform(data_training)

# %% [markdown]
# ## 3.2 Data scaling, reshaping, Model

# %%
current_datetime = datetime.datetime.today()
formatted_datetime = current_datetime.strftime('%Y-%m-%d %H:%M')

# %%
lstm_model, resultat, model_history, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test = \
LSTM_M1(FE_df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout)
# Out:
# Epoch 1/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0430
# Epoch 1: val_loss improved from inf to 0.00931, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 2s 28ms/step - loss: 0.0430 - val_loss: 0.0093
# Epoch 2/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0155
# Epoch 2: val_loss improved from 0.00931 to 0.00776, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0153 - val_loss: 0.0078
# Epoch 3/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0137
# Epoch 3: val_loss improved from 0.00776 to 0.00500, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0135 - val_loss: 0.0050
# Epoch 4/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0106
# Epoch 4: val_loss did not improve from 0.00500
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0106 - val_loss: 0.0073
# Epoch 5/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 5: val_loss did not improve from 0.00500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0102 - val_loss: 0.0070
# Epoch 6/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0094
# Epoch 6: val_loss improved from 0.00500 to 0.00496, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0093 - val_loss: 0.0050
# Epoch 7/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 7: val_loss did not improve from 0.00496
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0086 - val_loss: 0.0065
# Epoch 8/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 8: val_loss did not improve from 0.00496
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 9/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0079
# Epoch 9: val_loss did not improve from 0.00496
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 10/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 10: val_loss did not improve from 0.00496
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 11/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 11: val_loss improved from 0.00496 to 0.00479, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - val_loss: 0.0048
# Epoch 12/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 12: val_loss did not improve from 0.00479
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0066 - val_loss: 0.0056
# Epoch 13/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 13: val_loss did not improve from 0.00479
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 14/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 14: val_loss improved from 0.00479 to 0.00402, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0060 - val_loss: 0.0040
# Epoch 15/100
# 39/42 [==========================>...] - ETA: 0s - loss: 0.0055
# Epoch 15: val_loss did not improve from 0.00402
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0056 - val_loss: 0.0066
# Epoch 16/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 16: val_loss did not improve from 0.00402
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0055 - val_loss: 0.0119
# Epoch 17/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 17: val_loss did not improve from 0.00402
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 18/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 18: val_loss did not improve from 0.00402
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 19/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 19: val_loss did not improve from 0.00402
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 20/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 20: val_loss did not improve from 0.00402
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 21/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 21: val_loss improved from 0.00402 to 0.00399, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 22/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 22: val_loss did not improve from 0.00399
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 23/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 23: val_loss did not improve from 0.00399
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 24/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0040
# Epoch 24: val_loss improved from 0.00399 to 0.00370, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 25/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 25: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 26/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 26: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 27/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 27: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 28/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 28: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 29/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 29: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 30/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 30: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0039 - val_loss: 0.0048
# Epoch 31/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 31: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 32/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 32: val_loss did not improve from 0.00370
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0037 - val_loss: 0.0051
# Epoch 33/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 33: val_loss improved from 0.00370 to 0.00368, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 34/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 34: val_loss did not improve from 0.00368
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0035 - val_loss: 0.0048
# Epoch 35/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 35: val_loss improved from 0.00368 to 0.00326, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 36/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 36: val_loss did not improve from 0.00326
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 37/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 37: val_loss did not improve from 0.00326
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 38/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 38: val_loss did not improve from 0.00326
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 39/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 39: val_loss did not improve from 0.00326
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 40/100
# 39/42 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 40: val_loss did not improve from 0.00326
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 41/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 41: val_loss did not improve from 0.00326
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 42/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 42: val_loss improved from 0.00326 to 0.00321, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 43/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 43: val_loss did not improve from 0.00321
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 44/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 44: val_loss did not improve from 0.00321
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 45/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 45: val_loss did not improve from 0.00321
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 46/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 46: val_loss did not improve from 0.00321
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 47/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 47: val_loss did not improve from 0.00321
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 48/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 48: val_loss improved from 0.00321 to 0.00318, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 49/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 49: val_loss improved from 0.00318 to 0.00309, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 50/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 50: val_loss did not improve from 0.00309
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0047
# Epoch 51/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 51: val_loss did not improve from 0.00309
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0036 - val_loss: 0.0047
# Epoch 52/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 52: val_loss improved from 0.00309 to 0.00294, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 53/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 53: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 54/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 54: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 55/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 55: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 56/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 56: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 57/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 57: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 58/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 58: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 59/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 59: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 60/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 60: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 61/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 61: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 62/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 62: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 63/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 63: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 64/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 64: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 65/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 65: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 66/100
# 39/42 [==========================>...] - ETA: 0s - loss: 0.0032
# Epoch 66: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 67/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 67: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0031 - val_loss: 0.0041
# Epoch 68/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 68: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 69/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 69: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 70/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 70: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 71/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 71: val_loss did not improve from 0.00294
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 72/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 72: val_loss improved from 0.00294 to 0.00289, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 73/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 73: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 74/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 74: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 75/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 75: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 76/100
# 39/42 [==========================>...] - ETA: 0s - loss: 0.0036
# Epoch 76: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 77/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 77: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 78/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 78: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 79/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 79: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 80/100
# 39/42 [==========================>...] - ETA: 0s - loss: 0.0034
# Epoch 80: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 81/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 81: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 82/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 82: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 83/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 83: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 84/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 84: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 85/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 85: val_loss did not improve from 0.00289
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 86/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 86: val_loss improved from 0.00289 to 0.00264, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 87/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 87: val_loss did not improve from 0.00264
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 88/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 88: val_loss did not improve from 0.00264
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 89/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 89: val_loss did not improve from 0.00264
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 90/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 90: val_loss did not improve from 0.00264
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 91/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 91: val_loss did not improve from 0.00264
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 92/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 92: val_loss improved from 0.00264 to 0.00249, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 93/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 93: val_loss did not improve from 0.00249
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 94/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 94: val_loss improved from 0.00249 to 0.00245, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 95/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 95: val_loss did not improve from 0.00245
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 96/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 96: val_loss did not improve from 0.00245
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 97/100
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 97: val_loss did not improve from 0.00245
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 98/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 98: val_loss did not improve from 0.00245
# 42/42 [==============================] - 1s 22ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 99/100
# 41/42 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 99: val_loss improved from 0.00245 to 0.00238, saving model to models/M1\lstm_M1.h5
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 100/100
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 100: val_loss did not improve from 0.00238
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0027

# %%
resultat.insert(0, formatted_datetime)

# %% [markdown]
# # 4. Evaluation performance

# %% [markdown]
# ## 4.1. Scaled performance

# %%
def lstm_scaled_perfomance(model_history, start_epoch=1):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(start_epoch, start_epoch + len(model_history.history['loss']))
    
    # loss, val_loss 
    axs[0].plot(epochs, model_history.history['loss'], label='Training Loss')
    axs[0].plot(epochs, model_history.history['val_loss'],  label='Validation Loss')
    axs[0].set_title('Model Loss')
    axs[0].set_ylabel('Loss')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validation'], loc='best')
    
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(model_history.history).pow(.5)
    loss_history.index += 1    
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    best_epoch = loss_history.val_loss.idxmin()    
    title = f'Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
    loss_history.columns=['Training RMSE', 'Validation RMSE']
    
    loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=axs[1])    
    axs[1].axvline(best_epoch, ls='--', lw=1, c='k')
    
    sns.despine()
    fig.tight_layout()    
    plt.show()
    return best_rmse, best_epoch

# %%
best_rmse, best_epoch = lstm_scaled_perfomance(model_history)

# %%
y_train_predict_scaled = lstm_model.predict(X_train)
y_test_predict_scaled = lstm_model.predict(X_test)
# Out:
# 84/84 [==============================] - 1s 6ms/step
# 21/21 [==============================] - 0s 6ms/step

# %% [raw]
# Spearman's rank correlation coefficient, often denoted as ρ (rho), is a statistical measure that quantifies the strength and direction of a monotonic relationship between two variables. Instead of considering the actual values of the variables, it considers their ranks.
#
# The Spearman's rank correlation coefficient can take values between -1 and 1:
#
# ρ = 1: Perfect monotonic increasing relationship.
# ρ = -1: Perfect monotonic decreasing relationship.
# ρ = 0: No monotonic relationship.

# %%
from scipy.stats import spearmanr
train_ic = spearmanr(y_train, y_train_predict_scaled)[0]
test_ic = spearmanr(y_test, y_test_predict_scaled)[0]
print(f'Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}')
# Out:
# Train IC: 0.9981 | Test IC: 0.9664

# %%
resultat.extend([round(train_ic, 4), round(test_ic,4)])

# %%
import matplotlib.pyplot as plt

# Plotting the train and test predictions against actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_predict_scaled, label='Train Predictions')
plt.scatter(y_test, y_test_predict_scaled, label='Test Predictions')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Spearman rank correlation (IC)')
plt.legend()
plt.show()

# %% [markdown]
# ## 4.2. Rescaled performance

# %%
def lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    axs[0].plot(y_train_real, color = 'red', label = 'Real SP500 Price')
    axs[0].plot(y_train_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[0].set_title('SP500 Train Price Prediction')
    axs[0].set_ylabel('Price')
    axs[0].set_xlabel('Time')
    axs[0].legend(['Real', 'Predict'], loc='best')

    axs[1].plot(y_test_real, color = 'red', label = 'Real SP500 Price')
    axs[1].plot(y_test_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[1].set_title('SP500 Test Price Prediction')
    axs[1].set_ylabel('Price')
    axs[1].set_xlabel('Time')
    axs[1].legend(['Real', 'Predict'], loc='best')

    plt.legend()  
    plt.show()
    return

# %%
y_test_predict = y_scaler_test.inverse_transform(y_test_predict_scaled)
y_train_predict = y_scaler_train.inverse_transform(y_train_predict_scaled)

# %%
lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict)

# %%
train_rmse_scaled = np.sqrt(lstm_model.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm_model.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE: {train_rmse_scaled:.4f} | Test RMSE: {test_rmse_scaled:.4f}')
# Out:
# Train RMSE: 0.0166 | Test RMSE: 0.0524

# %%
resultat.extend([round(train_rmse_scaled, 4), round(test_rmse_scaled,4)])

# %%
train_rmse = np.sqrt(mean_squared_error(y_train_predict, y_train_real))
test_rmse = np.sqrt(mean_squared_error(y_test_predict, y_test_real))
f'Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}'
# Out:
# 'Train RMSE: 44.91 | Test RMSE: 79.93'

# %%
resultat.extend([round(train_rmse, 2), round(test_rmse,2)])

# %%
models_performance = pd.read_csv('models_performance.csv', index_col=[0])
models_performance.loc[len(models_performance)] = resultat
models_performance.to_csv('models_performance.csv')

# %%
def real_predict_dist(y_train_real, y_train_predict, y_test_real, y_test_predict):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    diff_train = y_train_predict - y_train_real
    diff_test = y_test_predict - y_test_real
    
# Création de l'histogramme de la distribution
    axs[0].hist(diff_train, bins=20, edgecolor='black')
# Ajout de labels et de titres
    axs[0].set_xlabel('Différence entre y_train_predict et y_train_real')
    axs[0].set_ylabel('Fréquence')
    axs[0].set_title('Distribution différence train')

    # Création de l'histogramme de la distribution
    axs[1].hist(diff_test, bins=20, edgecolor='black')
# Ajout de labels et de titres
    axs[1].set_xlabel('Différence entre y_test_predict et y_test_real')
    axs[1].set_ylabel('Fréquence')
    axs[1].set_title('Distribution différence test')

    plt.show()
    return

# %%
real_predict_dist(y_train_real, y_train_predict, y_test_real, y_test_predict)
