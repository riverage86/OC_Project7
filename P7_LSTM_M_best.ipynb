# %% [raw]
# LSTM M0 with best param

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
from datetime import date
import math
import pandas_datareader as web
import yfinance as yf
import time  # Import the time module
import os  # Import the os module
from sklearn.model_selection import TimeSeriesSplit

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
from pathlib import Path

# %% [markdown]
# # Parameters

# %%
win_size = 100
num_epoch = 150
num_cell = 100
batch_size = 10
dropout = 0.2
split_date = '2020-12-31'
# pour stocker les modèles 
results_path = Path('models', 'Best')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %%
# reshape 2D dataset (samples + features) en 3D (samples/time step + features + séquence) 
# en ajoutant la dimension fenêtre/séquence (longueur est window_size) N, pour prédire N+1. 
# y_pos est la position de colonnes du target. Normalament la prémière colonne
# dataset.shape[0] est le nombre des échantillons
def rnn_3D_data(dataset, window_size, y_pos=0): 
    X = []
    y = []
    for i in range(window_size, dataset.shape[0]):
        X.append(dataset[i-window_size: i])
        y.append(dataset[i, y_pos])
    X, y = np.array(X), np.array(y)
    return X, y

# %%
def data_retrieve(stock, start_date, end_date): 

# Define the list of tickers for the stocks you want to fetch data for
    tickers = [stock]

    # Define the list of stock indices and other features
    indices = ['^GSPC', '^DJI', '^IXIC', 'DX-Y.NYB', '^GDAXI', '^FTSE', '^N225', '^VIX']
    commodities = ['GC=F', 'BZ=F']
    forex = ['EURUSD=X', 'JPY=X']

    symbols = indices + commodities + forex
    # Fetch the historical data using yfinance for tickers (OHLC and Volume)
    ticker_data = yf.download(tickers, start=start_date, end=end_date)

    # Fetch the historical data using yfinance for indices and commodities (Close Price)
    close_data = yf.download(symbols, start=start_date, end=end_date)['Adj Close']

# Concatenate the close_data with the ticker_data to include Close Price for all symbols
    all_data = pd.concat([ticker_data, close_data], axis=1)

# Print the data
    return all_data

# %%
# Définir le modèle avec cycle scaling, reshing, compile, entrainement
def LSTM_M0(df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout):

    scalar = MinMaxScaler()

    data_training_scaled = scalar.fit_transform(data_training)
    X_train, y_train = rnn_3D_data(data_training_scaled, window_size=win_size, y_pos=4)
    
    # add the winodw before test data
    data_test = pd.concat([data_training.tail(win_size), data_testing], ignore_index=True)
    data_test_scaled = scalar.fit_transform(data_test)
    X_test, y_test = rnn_3D_data(data_test_scaled, window_size=win_size, y_pos=4)
    
    y_scaler_train = MinMaxScaler()
    y_scaler_train.fit(data_training["Close"].values.reshape(-1, 1))
    y_scaler_test = MinMaxScaler()
    y_scaler_test.fit(data_test["Close"].values.reshape(-1, 1))
    
    model = Sequential()

    model.add(LSTM(units = num_cell, input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units = 1, activation = 'sigmoid'))

    start_time = time.time()
    # Compiling the RNN
    model.compile(optimizer = 'adam', loss = 'mean_squared_error')
    
    rnn_path = (results_path / 'lstm_M0.h5').as_posix()
    checkpointer = ModelCheckpoint(filepath=rnn_path,
                               verbose=1,
                               monitor='val_loss',
                               save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=20,
                              restore_best_weights=True)
    
    lstm_training = model.fit(X_train, y_train, epochs=num_epoch, batch_size = batch_size,\
                        shuffle=True, validation_data=(X_test, y_test),\
                        callbacks=[early_stopping, checkpointer],
                        verbose=1)     
    
    end_time = time.time()
    execution_time = end_time - start_time   
    
    # evaluer le modèle
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(lstm_training.history).pow(.5)
    loss_history.index += 1
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    
    resultat = ['M0',win_size,num_cell, num_epoch, batch_size, dropout, round(best_rmse, 4), round(execution_time, 0)]
    return model, resultat, lstm_training, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test

# %% [markdown]
# # 1. Raw data collection

# %%
start_date = datetime.datetime(2010, 1, 2)
end_date = datetime.datetime.today()

# %%
raw_data = yf.download('^GSPC', start=start_date, end=end_date)
raw_data.to_parquet('sp500_data.parquet')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
raw_data.to_parquet('sp500_data.parquet')

# %%
data = pd.read_parquet('sp500_data.parquet')

# %%
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('There are {} number of days in the dataset.'.format(data.shape[0]))
# Out:
# There are 3430 number of days in the dataset.

# %%
plt.figure(figsize=(28, 12))#, dpi=100)
plt.plot(data.index, data['Adj Close'], label='SP500')
plt.xlabel('Date')
plt.ylabel('Rs')
plt.title('sp500')
plt.legend()
plt.show()

# %%
df = data.copy()
df = df.dropna()
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
print('Total dataset has {} samples, and {} features.'.format(df.shape[0], \
                                                              df.shape[1]))
# Out:
# Total dataset has 3430 samples, and 6 features.

# %% [markdown]
# # 2. Feature engineering

# %%
FE_df = df

# %%
len(FE_df)
# Out:
# 3430

# %% [markdown]
# # 3. Modèle processing

# %% [markdown]
# ## 3.1. Data split

# %%
data_training = FE_df[FE_df.index < split_date].copy()
data_training.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
# 2010-01-08  1140.520020  1145.390015  1136.219971  1144.979980  1144.979980
#
#                 Volume
# Date
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000
# 2010-01-08  4389590000

# %%
y_train_real_all = data_training["Close"].values.reshape(-1, 1)

# %%
#remove the first win_size row which are without prediction
y_train_real = y_train_real_all[win_size:]

# %%
data_testing = FE_df[FE_df.index >= split_date].copy()
data_testing.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
# 2021-01-04  3764.610107  3769.989990  3662.709961  3700.649902  3700.649902
# 2021-01-05  3698.020020  3737.830078  3695.070068  3726.860107  3726.860107
# 2021-01-06  3712.199951  3783.040039  3705.340088  3748.139893  3748.139893
# 2021-01-07  3764.709961  3811.550049  3764.709961  3803.790039  3803.790039
#
#                 Volume
# Date
# 2020-12-31  3179040000
# 2021-01-04  5015000000
# 2021-01-05  4591020000
# 2021-01-06  6064110000
# 2021-01-07  5099160000

# %%
y_test_real = data_testing["Close"].values.reshape(-1, 1)

# %% [raw]
# Normalization: MinMaxScaler transforms your data to a specific range, typically between 0 and 1. This is especially useful when you have features with different scales, as it ensures that all features are on a similar scale. This can be important for algorithms that are sensitive to the scale of features, like gradient-based optimization algorithms.
# Applied to all features.

# %%
#scalar = MinMaxScaler()

#data_training_scaled = scalar.fit_transform(data_training)

# %% [markdown]
# ## 3.2 Data scaling, reshaping, Model

# %%
current_datetime = datetime.datetime.today()
formatted_datetime = current_datetime.strftime('%Y-%m-%d %H:%M')

# %%
lstm_model, resultat, model_history, scalar,  X_train, y_train, X_test, y_test, y_scaler_train, y_scaler_test = \
LSTM_M0(FE_df, data_training, data_testing, win_size, num_epoch, num_cell, batch_size, dropout)
# Out:
# Epoch 1/150
# 267/267 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 1: val_loss improved from inf to 0.00462, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 15s 38ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 2/150
# 266/267 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 2: val_loss improved from 0.00462 to 0.00383, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 9s 35ms/step - loss: 0.0010 - val_loss: 0.0038
# Epoch 3/150
# 265/267 [============================>.] - ETA: 0s - loss: 7.9457e-04
# Epoch 3: val_loss improved from 0.00383 to 0.00332, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 7.9354e-04 - val_loss: 0.0033
# Epoch 4/150
# 267/267 [==============================] - ETA: 0s - loss: 6.3548e-04
# Epoch 4: val_loss improved from 0.00332 to 0.00289, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 31ms/step - loss: 6.3548e-04 - val_loss: 0.0029
# Epoch 5/150
# 265/267 [============================>.] - ETA: 0s - loss: 6.0533e-04
# Epoch 5: val_loss improved from 0.00289 to 0.00266, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 6.0415e-04 - val_loss: 0.0027
# Epoch 6/150
# 267/267 [==============================] - ETA: 0s - loss: 5.3847e-04
# Epoch 6: val_loss did not improve from 0.00266
# 267/267 [==============================] - 8s 29ms/step - loss: 5.3847e-04 - val_loss: 0.0027
# Epoch 7/150
# 266/267 [============================>.] - ETA: 0s - loss: 5.0029e-04
# Epoch 7: val_loss improved from 0.00266 to 0.00236, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 4.9934e-04 - val_loss: 0.0024
# Epoch 8/150
# 267/267 [==============================] - ETA: 0s - loss: 4.8127e-04
# Epoch 8: val_loss did not improve from 0.00236
# 267/267 [==============================] - 8s 29ms/step - loss: 4.8127e-04 - val_loss: 0.0029
# Epoch 9/150
# 265/267 [============================>.] - ETA: 0s - loss: 4.4416e-04
# Epoch 9: val_loss improved from 0.00236 to 0.00217, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 4.4405e-04 - val_loss: 0.0022
# Epoch 10/150
# 266/267 [============================>.] - ETA: 0s - loss: 4.0124e-04
# Epoch 10: val_loss did not improve from 0.00217
# 267/267 [==============================] - 9s 33ms/step - loss: 4.0378e-04 - val_loss: 0.0025
# Epoch 11/150
# 265/267 [============================>.] - ETA: 0s - loss: 4.0898e-04
# Epoch 11: val_loss improved from 0.00217 to 0.00217, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 4.0693e-04 - val_loss: 0.0022
# Epoch 12/150
# 265/267 [============================>.] - ETA: 0s - loss: 3.4956e-04
# Epoch 12: val_loss improved from 0.00217 to 0.00206, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 3.4932e-04 - val_loss: 0.0021
# Epoch 13/150
# 266/267 [============================>.] - ETA: 0s - loss: 3.6882e-04
# Epoch 13: val_loss improved from 0.00206 to 0.00192, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 3.6886e-04 - val_loss: 0.0019
# Epoch 14/150
# 266/267 [============================>.] - ETA: 0s - loss: 3.5950e-04
# Epoch 14: val_loss improved from 0.00192 to 0.00185, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 3.5964e-04 - val_loss: 0.0019
# Epoch 15/150
# 265/267 [============================>.] - ETA: 0s - loss: 3.4900e-04
# Epoch 15: val_loss improved from 0.00185 to 0.00181, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 3.4911e-04 - val_loss: 0.0018
# Epoch 16/150
# 266/267 [============================>.] - ETA: 0s - loss: 3.5785e-04
# Epoch 16: val_loss did not improve from 0.00181
# 267/267 [==============================] - 8s 29ms/step - loss: 3.5785e-04 - val_loss: 0.0020
# Epoch 17/150
# 267/267 [==============================] - ETA: 0s - loss: 3.1610e-04
# Epoch 17: val_loss improved from 0.00181 to 0.00168, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 3.1610e-04 - val_loss: 0.0017
# Epoch 18/150
# 267/267 [==============================] - ETA: 0s - loss: 3.4327e-04
# Epoch 18: val_loss did not improve from 0.00168
# 267/267 [==============================] - 8s 30ms/step - loss: 3.4327e-04 - val_loss: 0.0021
# Epoch 19/150
# 267/267 [==============================] - ETA: 0s - loss: 2.9906e-04
# Epoch 19: val_loss improved from 0.00168 to 0.00155, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 2.9906e-04 - val_loss: 0.0016
# Epoch 20/150
# 267/267 [==============================] - ETA: 0s - loss: 3.2258e-04
# Epoch 20: val_loss did not improve from 0.00155
# 267/267 [==============================] - 9s 33ms/step - loss: 3.2258e-04 - val_loss: 0.0017
# Epoch 21/150
# 267/267 [==============================] - ETA: 0s - loss: 3.0910e-04
# Epoch 21: val_loss improved from 0.00155 to 0.00151, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 3.0910e-04 - val_loss: 0.0015
# Epoch 22/150
# 265/267 [============================>.] - ETA: 0s - loss: 3.0725e-04
# Epoch 22: val_loss improved from 0.00151 to 0.00150, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 3.0692e-04 - val_loss: 0.0015
# Epoch 23/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.7155e-04
# Epoch 23: val_loss did not improve from 0.00150
# 267/267 [==============================] - 8s 29ms/step - loss: 2.7152e-04 - val_loss: 0.0017
# Epoch 24/150
# 267/267 [==============================] - ETA: 0s - loss: 3.0451e-04
# Epoch 24: val_loss did not improve from 0.00150
# 267/267 [==============================] - 8s 29ms/step - loss: 3.0451e-04 - val_loss: 0.0015
# Epoch 25/150
# 267/267 [==============================] - ETA: 0s - loss: 3.0831e-04
# Epoch 25: val_loss improved from 0.00150 to 0.00140, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 3.0831e-04 - val_loss: 0.0014
# Epoch 26/150
# 267/267 [==============================] - ETA: 0s - loss: 2.6802e-04
# Epoch 26: val_loss did not improve from 0.00140
# 267/267 [==============================] - 8s 29ms/step - loss: 2.6802e-04 - val_loss: 0.0016
# Epoch 27/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.6101e-04
# Epoch 27: val_loss improved from 0.00140 to 0.00139, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.6073e-04 - val_loss: 0.0014
# Epoch 28/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.8965e-04
# Epoch 28: val_loss improved from 0.00139 to 0.00135, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 7s 28ms/step - loss: 2.8891e-04 - val_loss: 0.0013
# Epoch 29/150
# 267/267 [==============================] - ETA: 0s - loss: 2.5827e-04
# Epoch 29: val_loss did not improve from 0.00135
# 267/267 [==============================] - 8s 29ms/step - loss: 2.5827e-04 - val_loss: 0.0014
# Epoch 30/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.5799e-04
# Epoch 30: val_loss improved from 0.00135 to 0.00132, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.5830e-04 - val_loss: 0.0013
# Epoch 31/150
# 267/267 [==============================] - ETA: 0s - loss: 2.5600e-04
# Epoch 31: val_loss improved from 0.00132 to 0.00132, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 2.5600e-04 - val_loss: 0.0013
# Epoch 32/150
# 267/267 [==============================] - ETA: 0s - loss: 2.4959e-04
# Epoch 32: val_loss improved from 0.00132 to 0.00129, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 2.4959e-04 - val_loss: 0.0013
# Epoch 33/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.5935e-04
# Epoch 33: val_loss did not improve from 0.00129
# 267/267 [==============================] - 8s 30ms/step - loss: 2.5994e-04 - val_loss: 0.0014
# Epoch 34/150
# 267/267 [==============================] - ETA: 0s - loss: 2.7270e-04
# Epoch 34: val_loss did not improve from 0.00129
# 267/267 [==============================] - 8s 29ms/step - loss: 2.7270e-04 - val_loss: 0.0013
# Epoch 35/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.6116e-04
# Epoch 35: val_loss improved from 0.00129 to 0.00122, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.6089e-04 - val_loss: 0.0012
# Epoch 36/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.1890e-04
# Epoch 36: val_loss did not improve from 0.00122
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1931e-04 - val_loss: 0.0013
# Epoch 37/150
# 267/267 [==============================] - ETA: 0s - loss: 2.4995e-04
# Epoch 37: val_loss did not improve from 0.00122
# 267/267 [==============================] - 8s 28ms/step - loss: 2.4995e-04 - val_loss: 0.0013
# Epoch 38/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.3658e-04
# Epoch 38: val_loss did not improve from 0.00122
# 267/267 [==============================] - 8s 29ms/step - loss: 2.3636e-04 - val_loss: 0.0013
# Epoch 39/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.2252e-04
# Epoch 39: val_loss improved from 0.00122 to 0.00117, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.2245e-04 - val_loss: 0.0012
# Epoch 40/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.3008e-04
# Epoch 40: val_loss did not improve from 0.00117
# 267/267 [==============================] - 8s 29ms/step - loss: 2.3004e-04 - val_loss: 0.0013
# Epoch 41/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.1851e-04
# Epoch 41: val_loss did not improve from 0.00117
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1873e-04 - val_loss: 0.0013
# Epoch 42/150
# 267/267 [==============================] - ETA: 0s - loss: 2.2511e-04
# Epoch 42: val_loss did not improve from 0.00117
# 267/267 [==============================] - 8s 29ms/step - loss: 2.2511e-04 - val_loss: 0.0012
# Epoch 43/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.1286e-04
# Epoch 43: val_loss improved from 0.00117 to 0.00116, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1261e-04 - val_loss: 0.0012
# Epoch 44/150
# 267/267 [==============================] - ETA: 0s - loss: 2.3124e-04
# Epoch 44: val_loss did not improve from 0.00116
# 267/267 [==============================] - 8s 29ms/step - loss: 2.3124e-04 - val_loss: 0.0012
# Epoch 45/150
# 267/267 [==============================] - ETA: 0s - loss: 2.2149e-04
# Epoch 45: val_loss did not improve from 0.00116
# 267/267 [==============================] - 8s 28ms/step - loss: 2.2149e-04 - val_loss: 0.0014
# Epoch 46/150
# 267/267 [==============================] - ETA: 0s - loss: 2.4084e-04
# Epoch 46: val_loss did not improve from 0.00116
# 267/267 [==============================] - 8s 29ms/step - loss: 2.4084e-04 - val_loss: 0.0012
# Epoch 47/150
# 267/267 [==============================] - ETA: 0s - loss: 2.3671e-04
# Epoch 47: val_loss did not improve from 0.00116
# 267/267 [==============================] - 8s 29ms/step - loss: 2.3671e-04 - val_loss: 0.0012
# Epoch 48/150
# 267/267 [==============================] - ETA: 0s - loss: 2.2132e-04
# Epoch 48: val_loss improved from 0.00116 to 0.00113, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.2132e-04 - val_loss: 0.0011
# Epoch 49/150
# 267/267 [==============================] - ETA: 0s - loss: 2.1944e-04
# Epoch 49: val_loss improved from 0.00113 to 0.00112, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1944e-04 - val_loss: 0.0011
# Epoch 50/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.0227e-04
# Epoch 50: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0198e-04 - val_loss: 0.0012
# Epoch 51/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.1929e-04
# Epoch 51: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1838e-04 - val_loss: 0.0016
# Epoch 52/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.1729e-04
# Epoch 52: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1693e-04 - val_loss: 0.0012
# Epoch 53/150
# 267/267 [==============================] - ETA: 0s - loss: 2.2239e-04
# Epoch 53: val_loss did not improve from 0.00112
# 267/267 [==============================] - 7s 28ms/step - loss: 2.2239e-04 - val_loss: 0.0012
# Epoch 54/150
# 267/267 [==============================] - ETA: 0s - loss: 2.1567e-04
# Epoch 54: val_loss did not improve from 0.00112
# 267/267 [==============================] - 7s 28ms/step - loss: 2.1567e-04 - val_loss: 0.0012
# Epoch 55/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.1813e-04
# Epoch 55: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1768e-04 - val_loss: 0.0012
# Epoch 56/150
# 267/267 [==============================] - ETA: 0s - loss: 2.0141e-04
# Epoch 56: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0141e-04 - val_loss: 0.0012
# Epoch 57/150
# 267/267 [==============================] - ETA: 0s - loss: 2.1123e-04
# Epoch 57: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1123e-04 - val_loss: 0.0011
# Epoch 58/150
# 267/267 [==============================] - ETA: 0s - loss: 2.0802e-04
# Epoch 58: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 28ms/step - loss: 2.0802e-04 - val_loss: 0.0013
# Epoch 59/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9623e-04
# Epoch 59: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9685e-04 - val_loss: 0.0012
# Epoch 60/150
# 267/267 [==============================] - ETA: 0s - loss: 2.1228e-04
# Epoch 60: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1228e-04 - val_loss: 0.0011
# Epoch 61/150
# 267/267 [==============================] - ETA: 0s - loss: 2.1719e-04
# Epoch 61: val_loss did not improve from 0.00112
# 267/267 [==============================] - 7s 28ms/step - loss: 2.1719e-04 - val_loss: 0.0012
# Epoch 62/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.2105e-04
# Epoch 62: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.2061e-04 - val_loss: 0.0012
# Epoch 63/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9700e-04
# Epoch 63: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9665e-04 - val_loss: 0.0011
# Epoch 64/150
# 267/267 [==============================] - ETA: 0s - loss: 2.2932e-04
# Epoch 64: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.2932e-04 - val_loss: 0.0012
# Epoch 65/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9904e-04
# Epoch 65: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9864e-04 - val_loss: 0.0011
# Epoch 66/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.0062e-04
# Epoch 66: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0110e-04 - val_loss: 0.0013
# Epoch 67/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.0230e-04
# Epoch 67: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 28ms/step - loss: 2.0273e-04 - val_loss: 0.0012
# Epoch 68/150
# 265/267 [============================>.] - ETA: 0s - loss: 2.1566e-04
# Epoch 68: val_loss did not improve from 0.00112
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1516e-04 - val_loss: 0.0013
# Epoch 69/150
# 267/267 [==============================] - ETA: 0s - loss: 2.0273e-04
# Epoch 69: val_loss improved from 0.00112 to 0.00111, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0273e-04 - val_loss: 0.0011
# Epoch 70/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.8982e-04
# Epoch 70: val_loss did not improve from 0.00111
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8928e-04 - val_loss: 0.0011
# Epoch 71/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.8941e-04
# Epoch 71: val_loss did not improve from 0.00111
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8942e-04 - val_loss: 0.0011
# Epoch 72/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9794e-04
# Epoch 72: val_loss improved from 0.00111 to 0.00107, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9794e-04 - val_loss: 0.0011
# Epoch 73/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9624e-04
# Epoch 73: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9582e-04 - val_loss: 0.0011
# Epoch 74/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.0248e-04
# Epoch 74: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 28ms/step - loss: 2.0247e-04 - val_loss: 0.0015
# Epoch 75/150
# 267/267 [==============================] - ETA: 0s - loss: 2.1381e-04
# Epoch 75: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 28ms/step - loss: 2.1381e-04 - val_loss: 0.0011
# Epoch 76/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.1448e-04
# Epoch 76: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 29ms/step - loss: 2.1476e-04 - val_loss: 0.0013
# Epoch 77/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.0556e-04
# Epoch 77: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0577e-04 - val_loss: 0.0011
# Epoch 78/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.9102e-04
# Epoch 78: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9089e-04 - val_loss: 0.0013
# Epoch 79/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.8775e-04
# Epoch 79: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8727e-04 - val_loss: 0.0012
# Epoch 80/150
# 267/267 [==============================] - ETA: 0s - loss: 2.0187e-04
# Epoch 80: val_loss did not improve from 0.00107
# 267/267 [==============================] - 7s 28ms/step - loss: 2.0187e-04 - val_loss: 0.0012
# Epoch 81/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.0382e-04
# Epoch 81: val_loss did not improve from 0.00107
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0374e-04 - val_loss: 0.0012
# Epoch 82/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.9398e-04
# Epoch 82: val_loss improved from 0.00107 to 0.00106, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 1.9524e-04 - val_loss: 0.0011
# Epoch 83/150
# 267/267 [==============================] - ETA: 0s - loss: 1.8849e-04
# Epoch 83: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8849e-04 - val_loss: 0.0011
# Epoch 84/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.8320e-04
# Epoch 84: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8309e-04 - val_loss: 0.0011
# Epoch 85/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.9930e-04
# Epoch 85: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9843e-04 - val_loss: 0.0012
# Epoch 86/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.8180e-04
# Epoch 86: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8151e-04 - val_loss: 0.0011
# Epoch 87/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.8812e-04
# Epoch 87: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8821e-04 - val_loss: 0.0012
# Epoch 88/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9001e-04
# Epoch 88: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9001e-04 - val_loss: 0.0012
# Epoch 89/150
# 267/267 [==============================] - ETA: 0s - loss: 2.0400e-04
# Epoch 89: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0400e-04 - val_loss: 0.0011
# Epoch 90/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.8608e-04
# Epoch 90: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8614e-04 - val_loss: 0.0011
# Epoch 91/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9493e-04
# Epoch 91: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9443e-04 - val_loss: 0.0011
# Epoch 92/150
# 266/267 [============================>.] - ETA: 0s - loss: 2.0901e-04
# Epoch 92: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 2.0893e-04 - val_loss: 0.0011
# Epoch 93/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9332e-04
# Epoch 93: val_loss improved from 0.00106 to 0.00106, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9332e-04 - val_loss: 0.0011
# Epoch 94/150
# 267/267 [==============================] - ETA: 0s - loss: 1.8933e-04
# Epoch 94: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 28ms/step - loss: 1.8933e-04 - val_loss: 0.0011
# Epoch 95/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9502e-04
# Epoch 95: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9502e-04 - val_loss: 0.0014
# Epoch 96/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9406e-04
# Epoch 96: val_loss did not improve from 0.00106
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9376e-04 - val_loss: 0.0011
# Epoch 97/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.8885e-04
# Epoch 97: val_loss improved from 0.00106 to 0.00105, saving model to models/Best\lstm_M0.h5
# 267/267 [==============================] - 8s 30ms/step - loss: 1.8890e-04 - val_loss: 0.0010
# Epoch 98/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.8893e-04
# Epoch 98: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8890e-04 - val_loss: 0.0011
# Epoch 99/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9705e-04
# Epoch 99: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9705e-04 - val_loss: 0.0011
# Epoch 100/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9575e-04
# Epoch 100: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9575e-04 - val_loss: 0.0011
# Epoch 101/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9875e-04
# Epoch 101: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9896e-04 - val_loss: 0.0012
# Epoch 102/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9295e-04
# Epoch 102: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9295e-04 - val_loss: 0.0011
# Epoch 103/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9092e-04
# Epoch 103: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9092e-04 - val_loss: 0.0011
# Epoch 104/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.8174e-04
# Epoch 104: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8299e-04 - val_loss: 0.0011
# Epoch 105/150
# 267/267 [==============================] - ETA: 0s - loss: 2.3901e-04
# Epoch 105: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 2.3901e-04 - val_loss: 0.0011
# Epoch 106/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9151e-04
# Epoch 106: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 28ms/step - loss: 1.9177e-04 - val_loss: 0.0011
# Epoch 107/150
# 267/267 [==============================] - ETA: 0s - loss: 1.8683e-04
# Epoch 107: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8683e-04 - val_loss: 0.0011
# Epoch 108/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.9354e-04
# Epoch 108: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 28ms/step - loss: 1.9323e-04 - val_loss: 0.0011
# Epoch 109/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.8083e-04
# Epoch 109: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8119e-04 - val_loss: 0.0010
# Epoch 110/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.7650e-04
# Epoch 110: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.7628e-04 - val_loss: 0.0011
# Epoch 111/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.7447e-04
# Epoch 111: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 28ms/step - loss: 1.7435e-04 - val_loss: 0.0011
# Epoch 112/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.8172e-04
# Epoch 112: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8109e-04 - val_loss: 0.0012
# Epoch 113/150
# 265/267 [============================>.] - ETA: 0s - loss: 1.8606e-04
# Epoch 113: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.8564e-04 - val_loss: 0.0011
# Epoch 114/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.7484e-04
# Epoch 114: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.7572e-04 - val_loss: 0.0011
# Epoch 115/150
# 267/267 [==============================] - ETA: 0s - loss: 1.9666e-04
# Epoch 115: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 29ms/step - loss: 1.9666e-04 - val_loss: 0.0011
# Epoch 116/150
# 267/267 [==============================] - ETA: 0s - loss: 1.7930e-04
# Epoch 116: val_loss did not improve from 0.00105
# 267/267 [==============================] - 7s 28ms/step - loss: 1.7930e-04 - val_loss: 0.0011
# Epoch 117/150
# 266/267 [============================>.] - ETA: 0s - loss: 1.8497e-04
# Epoch 117: val_loss did not improve from 0.00105
# 267/267 [==============================] - 8s 28ms/step - loss: 1.8469e-04 - val_loss: 0.0012

# %%
resultat.insert(0, formatted_datetime)

# %% [markdown]
# # 4. Evaluation performance

# %% [markdown]
# ## 4.1. Scaled performance

# %%
def lstm_scaled_perfomance(model_history, start_epoch=1):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    epochs = range(start_epoch, start_epoch + len(model_history.history['loss']))
    
    # loss, val_loss 
    axs[0].plot(epochs, model_history.history['loss'], label='Training Loss')
    axs[0].plot(epochs, model_history.history['val_loss'],  label='Validation Loss')
    axs[0].set_title('Model Loss')
    axs[0].set_ylabel('Loss')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validation'], loc='best')
    
    # transforme MSE en RMSE
    loss_history = pd.DataFrame(model_history.history).pow(.5)
    loss_history.index += 1    
#calcule la valeur minimale de la colonne val_loss dans le DataFrame loss_history, 
#ce qui correspond au meilleur RMSE de validation atteint par le modèle.
    best_rmse = loss_history.val_loss.min()
    best_epoch = loss_history.val_loss.idxmin()    
    title = f'Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
    loss_history.columns=['Training RMSE', 'Validation RMSE']
    
    loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=axs[1])    
    axs[1].axvline(best_epoch, ls='--', lw=1, c='k')
    
    sns.despine()
    fig.tight_layout()    
    plt.show()
    return best_rmse, best_epoch

# %%
best_rmse, best_epoch = lstm_scaled_perfomance(model_history)

# %%
y_train_predict_scaled = lstm_model.predict(X_train)
y_test_predict_scaled = lstm_model.predict(X_test)
# Out:
# 84/84 [==============================] - 5s 15ms/step
# 21/21 [==============================] - 3s 15ms/step

# %% [raw]
# Spearman's rank correlation coefficient, often denoted as ρ (rho), is a statistical measure that quantifies the strength and direction of a monotonic relationship between two variables. Instead of considering the actual values of the variables, it considers their ranks.
#
# The Spearman's rank correlation coefficient can take values between -1 and 1:
#
# ρ = 1: Perfect monotonic increasing relationship.
# ρ = -1: Perfect monotonic decreasing relationship.
# ρ = 0: No monotonic relationship.

# %%
from scipy.stats import spearmanr
train_ic = spearmanr(y_train, y_train_predict_scaled)[0]
test_ic = spearmanr(y_test, y_test_predict_scaled)[0]
print(f'Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}')
# Out:
# Train IC: 0.9990 | Test IC: 0.9830

# %%
resultat.extend([round(train_ic, 4), round(test_ic,4)])

# %%
import matplotlib.pyplot as plt

# Plotting the train and test predictions against actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_predict_scaled, label='Train Predictions')
plt.scatter(y_test, y_test_predict_scaled, label='Test Predictions')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Spearman rank correlation (IC)')
plt.legend()
plt.show()

# %% [markdown]
# ## 4.2. Rescaled performance

# %%
def lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    axs[0].plot(y_train_real, color = 'red', label = 'Real SP500 Price')
    axs[0].plot(y_train_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[0].set_title('SP500 Train Price Prediction')
    axs[0].set_ylabel('Price')
    axs[0].set_xlabel('Time')
    axs[0].legend(['Real', 'Predict'], loc='best')

    axs[1].plot(y_test_real, color = 'red', label = 'Real SP500 Price')
    axs[1].plot(y_test_predict, color = 'blue', label = 'Predicted SP500 Price')
    axs[1].set_title('SP500 Test Price Prediction')
    axs[1].set_ylabel('Price')
    axs[1].set_xlabel('Time')
    axs[1].legend(['Real', 'Predict'], loc='best')

    plt.legend()  
    plt.show()
    return

# %%
y_test_predict = y_scaler_test.inverse_transform(y_test_predict_scaled)
y_train_predict = y_scaler_train.inverse_transform(y_train_predict_scaled)

# %%
lstm_real_predict(y_train_real, y_train_predict, y_test_real, y_test_predict)

# %%
train_rmse_scaled = np.sqrt(lstm_model.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm_model.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE: {train_rmse_scaled:.4f} | Test RMSE: {test_rmse_scaled:.4f}')
# Out:
# Train RMSE: 0.0096 | Test RMSE: 0.0323

# %%
resultat.extend([round(train_rmse_scaled, 4), round(test_rmse_scaled,4)])

# %%
train_rmse = np.sqrt(mean_squared_error(y_train_predict, y_train_real))
test_rmse = np.sqrt(mean_squared_error(y_test_predict, y_test_real))
f'Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}'
# Out:
# 'Train RMSE: 25.94 | Test RMSE: 50.44'

# %%
resultat.extend([round(train_rmse, 2), round(test_rmse,2)])

# %%
models_performance = pd.read_csv('models_performance.csv', index_col=[0])
models_performance.loc[len(models_performance)] = resultat
models_performance.to_csv('models_performance.csv')

# %%
models_performance.head()
# Out:
#                Date Modele  win_size  num_cell  num_epoch  batch_size  \
# 0  2023-08-19 22:04     M0        60        50        100          64
# 1  2023-08-19 22:13     M0       100       100        150          10
#
#    dropout    rsme  train_duration(s)  IC_train  IC_test  rmse_train-scale  \
# 0      0.5  0.0488               43.0    0.9975    0.965            0.0170
# 1      0.2  0.0323              917.0    0.9990    0.983            0.0096
#
#    rmse_test_scale  rmse_train  rmse_test
# 0           0.0488       46.25      74.47
# 1           0.0323       25.94      50.44
